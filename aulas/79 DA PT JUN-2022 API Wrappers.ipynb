# %%
import pandas as pd
import numpy as np
import sqlalchemy as sa

# %%
1 == 2 or 3
# Out:
# 3

# %% [markdown]
# # API Wrappers
#
# No final da última aula vimos como construir um **wrapper** para uma API: uma classe que nos permite encapsular as etapas de autenticação e acesso à uma API. **Wrappers** nos permitem *abstrair* as camadas de conexão (como nosso script se comunicará com a API) das camadas de dados (o que vamos extrair de informação). Essa separação facilita a construção de códigos mais robustos - tanto à alterações na estrutura da API (simplificando o processo de atualização da camada de conexão) quanto aos requisitos de dados (simplificando o processo de alterações nos dados que extraímos).
#
# Muitas APIs contém **wrappers** pré-implementados através de bibliotecas, nos liberando para focar na extração e manipulação de dados e não na camada de conexão! Hoje veremos uma aplicação desenvolvida a partir do **wrapper** `spotipy` - uma biblioteca que facilita a conexão e extração de dados da plataforma de streaming **Spotify**.
#
# Alguns wrappers interessantes:
#
# * [Dados Abertos Brasil](https://pypi.org/project/DadosAbertosBrasil/)
# * [Dados Econômicos World Bank](https://pypi.org/project/wbgapi/)
# * [Meteostat para Dados Metereológicos](https://github.com/meteostat/meteostat-python)
# * [Yahoo! Finace](https://pypi.org/project/yfinance/)
# * [Lista extensiva de Wrappers Python](https://github.com/realpython/list-of-python-api-wrappers) para encontrar outros wrappers interessantes.
#
# Existem inúmeros wrappers pré-construídos - caso você deseje encontrar um wrapper para uma API específica seu melhor amigo será o Google (`python API nome_da_api`)!
#
# ## Lidando com autenticação
#
# Como vimos na aula passada, o acesso à muitas APIs é autenticado. É uma boa idéia separar as chaves de autenticação, por exemplo um `token`, do nosso código Python: se tornarmos nosso código público, via GitHub por exemplo, não queremos que outras pessoas utilizem nossas credenciais para acessar uma API!
#
# Podemos utilizar a biblioteca `dotenv` para *esconder* nossas chaves em um arquivo a parte do nosso código:
#
# - Instale a biblioteca usando `!pip install dotenv` (ou `!pip install python-dotenv`)
# - Crie um arquivo texto com a extensão `.env` na mesma pasta que o seu código Python
# - Insira as as suas chaves de autenticação utilizando a notação abaixo:
# ```
# API_KEY="l1noPOPAixCPM"
# API_SECRET="GraGq0zrGhs1qvbA0xQXsZBKuTkK5MJ"
# ```
# - Utilize a função `dotenv.load_dotenv('nome_do_seu_arquivo.env')`
# - Agora podemos utilizar a biblioteca `os` para recuperar as variáveis escritas no arquivo utilizando `os.getenv('API_KEY')`
#
# A idéia por trás desse procedimento é que podemos armazenar nossas chaves em um arquivo separado do nosso código. Agora podemos adicionar o arquivo `.env` ao nosso `.gitignore` para que ele não seja sincronizado com nosso repositório!

# %%
# !pip install python-dotenv

# %%
import os
from dotenv import load_dotenv

# %% [markdown]
# Agora vamos carregar o arquivo `exemplo_aula.env` e verificar que a variável `API_KEY` foi carregada corretamente:

# %%
load_dotenv('credentials/exemplo_aula.env')
# Out:
# True

# %%
print(os.getenv('api_secret'))
# Out:
# None

# %% [markdown]
# # Spotipy
#
# Para vermos como wrapper funcionam utilizaremos a biblioteca `spotipy`, que funciona como **wrapper para o Spotify**.
#
# A maior parte dos **wrappers** não fazem parte da instalação padrão do Anaconda, logo precisamos instalá-la utilizando `!pip`.

# %%
# !pip install spotipy

# %% [markdown]
# Além da própria biblioteca, vamos importar a classe `SpotifyClientCredentials` para fazer a autenticação na API do Spotify.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# ## Definindo o Problema
#
# Antes de mergulharmos na biblioteca `spotipy`, vamos entender o que queremos fazer com os dados desta API.
#
# Além de fornecer dados sobre a popularidade de artistas, músicas mais tocadas, etc, a API do Spotify fornece dados quantitativos sobre as músicas disponíveis no serviço de streaming. Essas informações são chamadas de *Audio Features*.
#
# Para entender o que são as *Audio Features* devemos ler a (extensa) [documentação](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-several-audio-features) da API.
#
# Nosso objetivo é utilizar essas informações (disponíveis por faixa) para quantificar e diferenciar festivais musicais acontencedo no verão de 2022 na Europa. O primeiro passo é carregar uma tabela com os dados de *headliners* para cada festival:

# %%
import pandas as pd

def read_from_gsheets(spreadsheet_link):
    """
    Transform Google Sheets URL into a CSV file
    """
    working_spreadsheet = spreadsheet_link.replace(
        "/edit?usp=sharing", "/export?format=csv"
    )

    return pd.read_csv(working_spreadsheet)

# %%
tb_festivals = read_from_gsheets(
    "https://docs.google.com/spreadsheets/d/1aUiwstZKEENiw3KAT1CCCXcji1iLWdCL_HwngvLxzJc/edit?usp=sharing"
)
tb_festivals.head(10)
# Out:
#        festival                 headliners
# 0  Tomorrowland              Martin Garrix
# 1  Tomorrowland           Armin van Buuren
# 2  Tomorrowland  Dimitri Vegas & Like Mike
# 3  Tomorrowland                 Marshmello
# 4  Tomorrowland                Amelie Lens
# 5  Tomorrowland                 Adam Beyer
# 6  Tomorrowland                 Eric Prydz
# 7  Tomorrowland                      NERVO
# 8   Glastonbury              Billie Eilish
# 9   Glastonbury             Paul McCartney

# %% [markdown]
# ## Conectando ao Spotify
#
# Para nos conectarmos com a API do Spotify precisamos criar um par de `CLIENT_ID` e `CLIENT_SECRET`. Podemos fazer isso através do dashboard de desenvolvedor do Spotify: https://developer.spotify.com.
#
# Vamos guardar o par de chaves criado em um arquivo `.env` e carrega-lo utilizando a função `load_dotenv`:

# %%
load_dotenv('credentials/spotify.env')
# Out:
# True

# %% [markdown]
# Agora vamos utilizar a classe `SpotifyClientCredentials` para criar o gerenciador de autenticação da API. Utilizando este gerenciador, podemos inicializar a conexão com a API utilizando a classe `spotipy.Spotify`:

# %%
auth_manager = SpotifyClientCredentials(
    client_id=os.getenv('CLIENT_ID'), 
    client_secret=os.getenv('CLIENT_SECRET')
)
spotify = spotipy.Spotify(client_credentials_manager=auth_manager)

# %% [markdown]
# ### Investigando Audio Features
#
# Vamos investigar o que são os *audio features* de algumas músicas para entender como extrair essa informação.
#
# Inicialmente, precisamos do *url* de cada faixa no Spotify:

# %%
dict_songs = {
    "kate_bush": "https://open.spotify.com/track/75FEaRjZTKLhTrFGsfMUXR?si=26398bff72014b5a",
    "slayer": "https://open.spotify.com/track/4fiOTntQKr24p07FvQDHZE?si=148a03ca6ba844fb",
    "nin": "https://open.spotify.com/track/27tX58NOpv1YKQ0abW7EPy?si=09484ca5e58d454a",
    "cardi_b": "https://open.spotify.com/track/58q2HKrzhC3ozto2nDdN4z?si=6f755b3e29d841ad",
}

# %% [markdown]
# Agora vamos utilizar o método `audio_features` para extrair, a partir de um URL de faixa do Spotify, os dados de uma música específica:

# %%
spotify.audio_features(dict_songs["kate_bush"])
# Out:
# [{'danceability': 0.629,
#   'energy': 0.547,
#   'key': 10,
#   'loudness': -13.123,
#   'mode': 0,
#   'speechiness': 0.055,
#   'acousticness': 0.72,
#   'instrumentalness': 0.00314,
#   'liveness': 0.0604,
#   'valence': 0.197,
#   'tempo': 108.375,
#   'type': 'audio_features',
#   'id': '75FEaRjZTKLhTrFGsfMUXR',
#   'uri': 'spotify:track:75FEaRjZTKLhTrFGsfMUXR',
#   'track_href': 'https://api.spotify.com/v1/tracks/75FEaRjZTKLhTrFGsfMUXR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/75FEaRjZTKLhTrFGsfMUXR',
#   'duration_ms': 298933,
#   'time_signature': 4}]

# %%
spotify.audio_features('https://open.spotify.com/track/3VSvkDLaaMUV6nFNcT4nxv?si=9c03f4cca9644cfc')
# Out:
# [{'danceability': 0.308,
#   'energy': 0.442,
#   'key': 2,
#   'loudness': -4.986,
#   'mode': 0,
#   'speechiness': 0.0301,
#   'acousticness': 0.265,
#   'instrumentalness': 9.61e-06,
#   'liveness': 0.494,
#   'valence': 0.536,
#   'tempo': 85.387,
#   'type': 'audio_features',
#   'id': '3VSvkDLaaMUV6nFNcT4nxv',
#   'uri': 'spotify:track:3VSvkDLaaMUV6nFNcT4nxv',
#   'track_href': 'https://api.spotify.com/v1/tracks/3VSvkDLaaMUV6nFNcT4nxv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3VSvkDLaaMUV6nFNcT4nxv',
#   'duration_ms': 197741,
#   'time_signature': 3}]

# %% [markdown]
# ## Conectando **Festivais** à **Audio Features**
#
# Agora que vimos como extrair *audio features* a partir de um URI de faixa, vamos mapear o caminho que utilizaremos para conectar nossa tabela de *headliners* aos *audio features*.
#
# Precisamos *sair* de uma tabela de **nomes de artista** para o **URI de faixa** para algumas faixas de cada artista. O primeiro passo então é buscar informações sobre o artista a partir do nome deste!
#
# ### Extraindo Artistas
#
# Para buscar *strings* na API do Spotify podemos utilizar o método `.search()`. Vamos utilizar este método para buscar um artista específico e investigar os resultados.

# %%
search_result = spotify.search(q="Cardi B", type="artist")
print(search_result)
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Cardi+B&type=artist&offset=0&limit=10', 'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'}, 'followers': {'href': None, 'total': 20630195}, 'genres': ['dance pop', 'pop', 'pop rap', 'rap'], 'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB', 'id': '4kYSro6naA4h99UJvo89HB', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb8c2332e6c0ed96d144a91b3f', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051748c2332e6c0ed96d144a91b3f', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1788c2332e6c0ed96d144a91b3f', 'width': 160}], 'name': 'Cardi B', 'popularity': 81, 'type': 'artist', 'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/48Zfxc7ffSnNO0VMbY0Sg8'}, 'followers': {'href': None, 'total': 92}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/48Zfxc7ffSnNO0VMbY0Sg8', 'id': '48Zfxc7ffSnNO0VMbY0Sg8', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb7f2a6fa259582faf82580555', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051747f2a6fa259582faf82580555', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1787f2a6fa259582faf82580555', 'width': 160}], 'name': 'Cardi Beatzz', 'popularity': 16, 'type': 'artist', 'uri': 'spotify:artist:48Zfxc7ffSnNO0VMbY0Sg8'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0yeXJ3PflYqGbU9IcdO4R4'}, 'followers': {'href': None, 'total': 4778}, 'genres': ['banjo', 'bluegrass', 'bluegrass gospel', 'traditional bluegrass'], 'href': 'https://api.spotify.com/v1/artists/0yeXJ3PflYqGbU9IcdO4R4', 'id': '0yeXJ3PflYqGbU9IcdO4R4', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27301fd1412d123d6516cd654e0', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0201fd1412d123d6516cd654e0', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485101fd1412d123d6516cd654e0', 'width': 64}], 'name': 'The Bluegrass Cardinals', 'popularity': 26, 'type': 'artist', 'uri': 'spotify:artist:0yeXJ3PflYqGbU9IcdO4R4'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/1r29dFdSenwksTQdkH7r6I'}, 'followers': {'href': None, 'total': 28581}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/1r29dFdSenwksTQdkH7r6I', 'id': '1r29dFdSenwksTQdkH7r6I', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb82e4bde11800287191718eed', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab6761610000517482e4bde11800287191718eed', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f17882e4bde11800287191718eed', 'width': 160}], 'name': 'lil Shordie Scott', 'popularity': 58, 'type': 'artist', 'uri': 'spotify:artist:1r29dFdSenwksTQdkH7r6I'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3iOLvsVNy0wG6qfpk6vjKW'}, 'followers': {'href': None, 'total': 71}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/3iOLvsVNy0wG6qfpk6vjKW', 'id': '3iOLvsVNy0wG6qfpk6vjKW', 'images': [], 'name': 'Cardi B and Family', 'popularity': 14, 'type': 'artist', 'uri': 'spotify:artist:3iOLvsVNy0wG6qfpk6vjKW'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/05Q6Bk1mvYf0s8hlNJnd73'}, 'followers': {'href': None, 'total': 14283}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/05Q6Bk1mvYf0s8hlNJnd73', 'id': '05Q6Bk1mvYf0s8hlNJnd73', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebe15965379f0f3aa5d3d7da31', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174e15965379f0f3aa5d3d7da31', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178e15965379f0f3aa5d3d7da31', 'width': 160}], 'name': 'Cardiff Brothers', 'popularity': 27, 'type': 'artist', 'uri': 's ...

# %% [markdown]
# Um dicionário bem complexo... Podemos tentar tratar esse dicionário utilizando a função `json_normalize()` da biblioteca Pandas:

# %%
pd.json_normalize(search_result)
# Out:
#                                         artists.href  \
# 0  https://api.spotify.com/v1/search?query=Cardi+...
#
#                                        artists.items  artists.limit  \
# 0  [{'external_urls': {'spotify': 'https://open.s...             10
#
#                                         artists.next  artists.offset  \
# 0  https://api.spotify.com/v1/search?query=Cardi+...               0
#
#   artists.previous  artists.total
# 0             None            104

# %% [markdown]
# Obviamente o resultado não foi o esperado... Precisamos investigar mais diretamente o resultado do método:

# %%
search_result.keys()
# Out:
# dict_keys(['artists'])

# %%
search_result['artists'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
search_result['artists']['items'][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [66], in <cell line: 1>()
# ----> 1 search_result['artists']['items'][0]
#
# IndexError: list index out of range

# %% [markdown]
# Com o URI em mãos, podemos utilizar o método `.artist()` para trazer apenas um artista específico:

# %%
dict_cardib = search_result['artists']['items'][0]
dict_cardib
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#  'followers': {'href': None, 'total': 20630195},
#  'genres': ['dance pop', 'pop', 'pop rap', 'rap'],
#  'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#  'id': '4kYSro6naA4h99UJvo89HB',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb8c2332e6c0ed96d144a91b3f',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab676161000051748c2332e6c0ed96d144a91b3f',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f1788c2332e6c0ed96d144a91b3f',
#    'width': 160}],
#  'name': 'Cardi B',
#  'popularity': 81,
#  'type': 'artist',
#  'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'}

# %%
dict_cardib['uri']
# Out:
# 'spotify:artist:4kYSro6naA4h99UJvo89HB'

# %%
spotify.artist('spotify:artist:4kYSro6naA4h99UJvo89HB')
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#  'followers': {'href': None, 'total': 20630195},
#  'genres': ['dance pop', 'pop', 'pop rap', 'rap'],
#  'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#  'id': '4kYSro6naA4h99UJvo89HB',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb8c2332e6c0ed96d144a91b3f',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab676161000051748c2332e6c0ed96d144a91b3f',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f1788c2332e6c0ed96d144a91b3f',
#    'width': 160}],
#  'name': 'Cardi B',
#  'popularity': 81,
#  'type': 'artist',
#  'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'}

# %% [markdown]
# ### Extraindo Faixas
#
# Agora precisamos transformar o URI de artista em um conjunto de faixas. Como extrair todas as músicas de um dado artista pode demorar muito, vamos utilizar o método `.artist_top_tracks()` para extrair dados das 10 maiores músicas de cada artista:

# %%
top_10_tracks = spotify.artist_top_tracks(dict_cardib['uri'])
top_10_tracks
# Out:
# {'tracks': [{'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#       'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#       'id': '4kYSro6naA4h99UJvo89HB',
#       'name': 'Cardi B',
#       'type': 'artist',
#       'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hcs9uc56yIGFCSy9leWe7'},
#       'href': 'https://api.spotify.com/v1/artists/3hcs9uc56yIGFCSy9leWe7',
#       'id': '3hcs9uc56yIGFCSy9leWe7',
#       'name': 'Lil Durk',
#       'type': 'artist',
#       'uri': 'spotify:artist:3hcs9uc56yIGFCSy9leWe7'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2qTIltFPwJzsyssGeOwdRO'},
#     'href': 'https://api.spotify.com/v1/albums/2qTIltFPwJzsyssGeOwdRO',
#     'id': '2qTIltFPwJzsyssGeOwdRO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b629e669238964a725937c1b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b629e669238964a725937c1b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b629e669238964a725937c1b',
#       'width': 64}],
#     'name': 'Hot Shit (feat. Ye & Lil Durk)',
#     'release_date': '2022-07-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2qTIltFPwJzsyssGeOwdRO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#      'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#      'id': '4kYSro6naA4h99UJvo89HB',
#      'name': 'Cardi B',
#      'type': 'artist',
#      'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#      'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#      'id': '5K4W6rqBFWDnAN6FQUkS6x',
#      'name': 'Kanye West',
#      'type': 'artist',
#      'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hcs9uc56yIGFCSy9leWe7'},
#      'href': 'https://api.spotify.com/v1/artists/3hcs9uc56yIGFCSy9leWe7',
#      'id': '3hcs9uc56yIGFCSy9leWe7',
#      'name': 'Lil Durk',
#      'type': 'artist',
#      'uri': 'spotify:artist:3hcs9uc56yIGFCSy9leWe7'}],
#    'disc_number': 1,
#    'duration_ms': 211649,
#    'explicit': True,
#    'external_ids': {'isrc': 'USAT22208514'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3uJFmluXzYedoJcvhpC1AW'},
#    'href': 'https://api.spotify.com/v1/tracks/3uJFmluXzYedoJcvhpC1AW',
#    'id': '3uJFmluXzYedoJcvhpC1AW',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Hot Shit (feat. Ye & Lil Durk)',
#    'popularity': 81,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3b7bb38fd34d6cc497b18456924866c558626d79?cid=cd9cd1ff2710474993b146e14b5e2612',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3uJFmluXzYedoJcvhpC1AW'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#       'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#       'id': '4kYSro6naA4h99UJvo89HB',
#       'name': 'Cardi B',
#       'type': 'artist',
#       'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/181bsRPaVXVlUKXrxwZfHK'},
#       'href': 'https://api.spotify.com/v1/artists/181bsRPaVXVlUKXrxwZfHK',
#       'id': '181bsRPaVXVlUKXrxwZfHK',
#       'name': 'Megan Thee Stallion',
#       'type': 'artist',
#       'uri': 'spotify:artist:181bsRPaVXVlUKXrxwZfHK'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2ogiazbrNEx0kQHGl5ZBTQ'},
#     'href': 'https://api.spotify.com/v1/albums/2ogiazbrNEx0kQHGl5ZBTQ',
#     'id': '2ogiazbrNEx0kQHGl5ZBTQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c450c89d3eb750d3535b0a0c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c450c89d3eb750d3535b0a0c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c450c89d3eb750d3535b0a0c',
#       'width': 64}],
#     'name': 'WAP (feat. Megan Thee Stallion)',
#     'release_date': '2020-08-07',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2ogiazbrNEx0kQHGl5ZBTQ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#      'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#      'id': '4kYSro6naA4h99UJvo89HB',
#      'name': 'Cardi B',
#      'type': 'artist',
#      'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/181bsRPaVXVlUKXrxwZfHK'},
#      'href': 'https://api.spotify.com/v1/artists/181bsRPaVXVlUKXrxwZfHK',
#      'id': '181bsRPaVXVlUKXrxwZfHK',
#      'name': 'Megan Thee Stallion',
#      'type': 'artist',
#      'uri': 'spotify:artist:181bsRPaVXVlUKXrxwZfHK'}],
#    'disc_number': 1,
#    'duration_ms': 187541,
#    'explicit': True,
#    'external_ids': {'isrc': 'USAT22005111'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4Oun2ylbjFKMPTiaSbbCih'},
#    'href': 'https://api.spotify.com/v1/tracks/4Oun2ylbjFKMPTiaSbbCih',
#    'id': '4Oun2ylbjFKMPTiaSbbCih',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'WAP (feat. Megan Thee Stallion)',
#    'popularity': 80,
#    'preview_url': 'https://p.scdn.co/mp3-preview/37c24a25c0a691bf21c4d9cb0007c71608419d35?cid=cd9cd1ff2710474993b146e14b5e2612',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4Oun2ylbjFKMPTiaSbbCih'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#       'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#       'id': '4kYSro6naA4h99UJvo89HB',
#       'name': 'Cardi B',
#       'type': 'artist',
#       'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4KdtEKjY3Gi0mKiSdy96ML'},
#     'href': 'https://api.spotify.com/v1/albums/4KdtEKjY3Gi0mKiSdy96ML',
#     'id': '4KdtEKjY3Gi0mKiSdy96ML',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a0caffda54afd0a65995bbab',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a0caffda54afd0a65995bbab',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a0caffda54afd0a65995bbab',
#       'width': 64}],
#     'name': 'Invasion of Privacy',
#     'release_date': '2018-04-06',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:4KdtEKjY3Gi0mKiSdy96ML'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#      'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#      'id': '4kYSro6naA4h99UJvo89HB',
#      'name': 'Cardi B',
#      'type': 'artist',
#      'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#      'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#      'id': '4q3ewBCX7sLwd24euuV69X',
#      'name': 'Bad Bunny',
#      'type': 'artist',
#      'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1vyhD5VmyZ7KMfW5gqLgo5'},
#      'href': 'https://api.spotify.com/v1/artists/1vyhD5VmyZ7KMfW5gqLgo5',
#      'id': '1vyhD5VmyZ7KMfW5gqLgo5',
#      'name': 'J Balvin',
#      'type': 'artist',
#      'uri': 'spotify:artist:1vyhD5VmyZ7KMfW5gqLgo5'}],
#    'disc_number': 1,
#    'duration_ms': 253390,
#    'explicit': True,
#    'external_ids': {'isrc': 'USAT21801431'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/58q2HKrzhC3ozto2nDdN4z'},
#    'href': 'https://api.spotify.com/v1/tracks/58q2HKrzhC3ozto2nDdN4z',
#    'id': '58q2HKrzhC3ozto2nDdN4z',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'I Like It',
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/dd236952548f554253f11b2c4c9f2ce1fb7f5b66?cid=cd9cd1ff2710474993b146e14b5e2612',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:58q2HKrzhC3ozto2nDdN4z'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3oIFxDIo2fwuk4lwCmFZCx'},
#     'href': 'https://api.spotify.com/v1/albums/3oIFxDIo2fwuk4lwCmFZCx',
#     'id': '3oIFxDIo2fwuk4lwCmFZCx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27373304ce0653c7758dd94b259',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0273304ce0653c7758dd94b259',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485173304ce0653c7758dd94b259',
#       'width': 64}],
#     'name': 'No.6 Collaborations Project',
#     'release_date': '2019-07-12',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:3oIFxDIo2fwuk4lwCmFZCx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#      'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#      'id': '6eUKZXaKkcviH0Ku9w2n3V',
#      'name': 'Ed Sheeran',
#      'type': 'artist',
#      'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4nDoRrQiYLoBzwC5BhVJzF'},
#      'href': 'https://api.spotify.com/v1/artists/4nDoRrQiYLoBzwC5BhVJzF',
#      'id': '4nDoRrQiYLoBzwC5BhVJzF',
#      'name': 'Camila Cabello',
#      'type': 'artist',
#      'uri': 'spotify:artist:4nDoRrQiYLoBzwC5BhVJzF'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#      'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#      'id': '4kYSro6naA4h99UJvo89HB',
#      'name': 'Cardi B',
#      'type': 'artist',
#      'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'}],
#    'disc_number': 1,
#    'duration_ms': 204466,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAHS1900714'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4vUmTMuQqjdnvlZmAH61Qk'},
#    'href': 'https://api.spotify.com/v1/tracks/4vUmTMuQqjdnvlZmAH61Qk',
#    'id': '4vUmTMuQqjdnvlZmAH61Qk',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'South of the Border (feat. Camila Cabello & Cardi B)',
#    'popularity': 76,
#    'preview_url': 'https://p.scdn.co/mp3-preview/961c2ee475d22044782f3c5159b02cdf92617f65?cid=cd9cd1ff2710474993b146e14b5e2612',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:4vUmTMuQqjdnvlZmAH61Qk'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/56oDRnqbIiwx4mymNEv7dS'},
#       'href': 'https://api.spotify.com/v1/artists/56oDRnqbIiwx4mymNEv7dS',
#       'id': '56oDRnqbIiwx4mymNEv7dS',
#       'name': 'Lizzo',
#       'type': 'artist',
#       'uri': 'spotify:artist:56oDRnqbIiwx4mymNEv7dS'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#       'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#       'id': '4kYSro6naA4h99UJvo89HB',
#       'name': 'Cardi B',
#       'type': 'artist',
#       'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7jMo8dhMIorHoLlzTisjJy'},
#     'href': 'https://api.spotify.com/v1/albums/7jMo8dhMIorHoLlzTisjJy',
#     'id': '7jMo8dhMIorHoLlzTisjJy',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273324290e5b99a797b99e247bb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02324290e5b99a797b99e247bb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851324290e5b99a797b99e247bb',
#       'width': 64}],
#     'name': 'Rumors (feat. Cardi B)',
#     'release_date': '2021-08-13',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7jMo8dhMIorHoLlzTisjJy'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/56oDRnqbIiwx4mymNEv7dS'},
#      'href': 'https://api.spotify.com/v1/artists/56oDRnqbIiwx4mymNEv7dS',
#      'id': '56oDRnqbIiwx4mymNEv7dS',
#      'name': 'Lizzo',
#      'type': 'artist',
#      'uri': 'spotify:artist:56oDRnqbIiwx4mymNEv7dS'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#      'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#      'id': '4kYSro6naA4h99UJvo89HB',
#      'name': 'Cardi B',
#      'type': 'artist',
#      'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'}],
#    'disc_number': 1,
#    'duration_ms': 172832,
#    'explicit': True,
#    'external_ids': {'isrc': 'USAT22104137'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6KgtcmCF9Ky68XC7ezxl3s'},
#    'href': 'https://api.spotify.com/v1/tracks/6KgtcmCF9Ky68XC7ezxl3s',
#    'id': '6KgtcmCF9Ky68XC7ezxl3s',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Rumors (feat. Cardi B)',
#    'popularity': 74,
#    'preview_url': 'https://p.scdn.co/mp3-preview/28b6326bee4e9e42827a6cd6ad4494b09e127169?cid=cd9cd1ff2710474993b146e14b5e2612',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6KgtcmCF9Ky68XC7ezxl3s'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#       'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#       'id': '0du5cEVh5yTK9QJze8zA0C',
#       'name': 'Bruno Mars',
#       'type': 'artist',
#       'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#       'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#       'id': '4kYSro6naA4h99UJvo89HB',
#       'name': 'Cardi B',
#       'type': 'artist',
#       'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3mumK2ar9b4JPhVOZR0V2p'},
#     'href': 'https://api.spotify.com/v1/albums/3mumK2ar9b4JPhVOZR0V2p',
#     'id': '3mumK2ar9b4JPhVOZR0V2p',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27347e522adf030a78615cdea06',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0247e522adf030a78615cdea06',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485147e522adf030a78615cdea06',
#       'width': 64}],
#     'name': 'Finesse (Remix) [feat. Cardi B]',
#     'release_date': '2017-12-20',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3mumK2ar9b4JPhVOZR0V2p'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#      'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#      'id': '0du5cEVh5yTK9QJze8zA0C',
#      'name': 'Bruno Mars',
#      'type': 'artist',
#      'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#      'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#      'id': '4kYSro6naA4h99UJvo89HB',
#      'name': 'Cardi B',
#      'type': 'artist',
#      'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'}],
#    'disc_number': 1,
#    'duration_ms': 217288,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21705441'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3Vo4wInECJQuz9BIBMOu8i'},
#    'href': 'https://api.spotify.com/v1/tracks/3Vo4wInECJQuz9BIBMOu8i',
#    'id': '3Vo4wInECJQuz9BIBMOu8i',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Finesse - Remix; feat. Cardi B',
#    'popularity': 74,
#    'preview_url': 'https://p.scdn.co/mp3-preview/6a5a8bc3f40a9a30c5af446ad60c0d862a77e573?cid=cd9cd1ff2710474993b146e14b5e2612',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3Vo4wInECJQuz9BIBMOu8i'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#       'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#       'id': '4kYSro6naA4h99UJvo89HB',
#       'name': 'Cardi B',
#       'type': 'artist',
#       'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0Fe4Uj7GkgA1uDGGk8s92C'},
#     'href': 'https://api.spotify.com/v1/albums/0Fe4Uj7GkgA1uDGGk8s92C',
#     'id': '0Fe4Uj7GkgA1uDGGk8s92C',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273199f2f07a9be49f2c930299a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02199f2f07a9be49f2c930299a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851199f2f07a9be49f2c930299a',
#       'width': 64}],
#     'name': 'Up (Instrumental)',
#     'release_date': '2021-02-04',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:0Fe4Uj7GkgA1uDGGk8s92C'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#      'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#      'id': '4kYSro6naA4h99UJvo89HB',
#      'name': 'Cardi B',
#      'type': 'artist',
#      'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'}],
#    'disc_number': 1,
#    'duration_ms': 156944,
#    'explicit': True,
#    'external_ids': {'isrc': 'USAT22100061'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1M4OcYkxAtu3ErzSgDEfoi'},
#    'href': 'https://api.spotify.com/v1/tracks/1M4OcYkxAtu3ErzSgDEfoi',
#    'id': '1M4OcYkxAtu3ErzSgDEfoi',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Up',
#    'popularity': 70,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c71424ce4db24cfba2fd49f56877242a2fb7a1e4?cid=cd9cd1ff2710474993b146e14b5e2612',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:1M4OcYkxAtu3ErzSgDEfoi'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#       'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#       'id': '4kYSro6naA4h99UJvo89HB',
#       'name': 'Cardi B',
#       'type': 'artist',
#       'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#       'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#       'id': '0du5cEVh5yTK9QJze8zA0C',
#       'name': 'Bruno Mars',
#       'type': 'artist',
#       'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5a4sJJ3qjn6hqRsvm0Veso'},
#     'href': 'https://api.spotify.com/v1/albums/5a4sJJ3qjn6hqRsvm0Veso',
#     'id': '5a4sJJ3qjn6hqRsvm0Veso',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273288883647008cefba0db5402',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02288883647008cefba0db5402',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851288883647008cefba0db5402',
#       'width': 64}],
#     'name': 'Please Me',
#     'release_date': '2019-02-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5a4sJJ3qjn6hqRsvm0Veso'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#      'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#      'id': '4kYSro6naA4h99UJvo89HB',
#      'name': 'Cardi B',
#      'type': 'artist',
#      'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#      'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#      'id': '0du5cEVh5yTK9QJze8zA0C',
#      'name': 'Bruno Mars',
#      'type': 'artist',
#      'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#    'disc_number': 1,
#    'duration_ms': 200889,
#    'explicit': True,
#    'external_ids': {'isrc': 'USAT21811659'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0PG9fbaaHFHfre2gUVo7AN'},
#    'href': 'https://api.spotify.com/v1/tracks/0PG9fbaaHFHfre2gUVo7AN',
#    'id': '0PG9fbaaHFHfre2gUVo7AN',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Please Me',
#    'popularity': 73,
#    'preview_url': 'https://p.scdn.co/mp3-preview/83f5801adf5325fcc5dfe0cb4cb8497ea84723fb?cid=cd9cd1ff2710474993b146e14b5e2612',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0PG9fbaaHFHfre2gUVo7AN'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AMeiDbfU2vonrTkpXDKUu'},
#       'href': 'https://api.spotify.com/v1/artists/2AMeiDbfU2vonrTkpXDKUu',
#       'id': '2AMeiDbfU2vonrTkpXDKUu',
#       'name': 'Kay Flock',
#       'type': 'artist',
#       'uri': 'spotify:artist:2AMeiDbfU2vonrTkpXDKUu'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#       'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#       'id': '4kYSro6naA4h99UJvo89HB',
#       'name': 'Cardi B',
#       'type': 'artist',
#       'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6ykgQbKcZFy5qoKBU4YiWj'},
#       'href': 'https://api.spotify.com/v1/artists/6ykgQbKcZFy5qoKBU4YiWj',
#       'id': '6ykgQbKcZFy5qoKBU4YiWj',
#       'name': 'Dougie B',
#       'type': 'artist',
#       'uri': 'spotify:artist:6ykgQbKcZFy5qoKBU4YiWj'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0Kr65MJsLayLENRXxrlW3Z'},
#     'href': 'https://api.spotify.com/v1/albums/0Kr65MJsLayLENRXxrlW3Z',
#     'id': '0Kr65MJsLayLENRXxrlW3Z',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273868b51c3a8d2376ef84ffeba',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02868b51c3a8d2376ef84ffeba',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851868b51c3a8d2376ef84ffeba',
#       'width': 64}],
#     'name': 'Shake It (feat. Cardi B, Dougie B & Bory300)',
#     'release_date': '2022-04-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0Kr65MJsLayLENRXxrlW3Z'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AMeiDbfU2vonrTkpXDKUu'},
#      'href': 'https://api.spotify.com/v1/artists/2AMeiDbfU2vonrTkpXDKUu',
#      'id': '2AMeiDbfU2vonrTkpXDKUu',
#      'name': 'Kay Flock',
#      'type': 'artist',
#      'uri': 'spotify:artist:2AMeiDbfU2vonrTkpXDKUu'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#      'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#      'id': '4kYSro6naA4h99UJvo89HB',
#      'name': 'Cardi B',
#      'type': 'artist',
#      'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6ykgQbKcZFy5qoKBU4YiWj'},
#      'href': 'https://api.spotify.com/v1/artists/6ykgQbKcZFy5qoKBU4YiWj',
#      'id': '6ykgQbKcZFy5qoKBU4YiWj',
#      'name': 'Dougie B',
#      'type': 'artist',
#      'uri': 'spotify:artist:6ykgQbKcZFy5qoKBU4YiWj'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/77oGJAObEl8wdAUrknL1gH'},
#      'href': 'https://api.spotify.com/v1/artists/77oGJAObEl8wdAUrknL1gH',
#      'id': '77oGJAObEl8wdAUrknL1gH',
#      'name': 'Bory300',
#      'type': 'artist',
#      'uri': 'spotify:artist:77oGJAObEl8wdAUrknL1gH'}],
#    'disc_number': 1,
#    'duration_ms': 118249,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM72205092'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0RkCnqwF8Tfl2QGPZwopyk'},
#    'href': 'https://api.spotify.com/v1/tracks/0RkCnqwF8Tfl2QGPZwopyk',
#    'id': '0RkCnqwF8Tfl2QGPZwopyk',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Shake It (feat. Cardi B, Dougie B & Bory300)',
#    'popularity': 72,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0RkCnqwF8Tfl2QGPZwopyk'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cWZOOzeOm4WmBJRnD5R7I'},
#       'href': 'https://api.spotify.com/v1/artists/2cWZOOzeOm4WmBJRnD5R7I',
#       'id': '2cWZOOzeOm4WmBJRnD5R7I',
#       'name': 'Normani',
#       'type': 'artist',
#       'uri': 'spotify:artist:2cWZOOzeOm4WmBJRnD5R7I'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#       'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#       'id': '4kYSro6naA4h99UJvo89HB',
#       'name': 'Cardi B',
#       'type': 'artist',
#       'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/16maAu5lqvFBSEEHyB5GzV'},
#     'href': 'https://api.spotify.com/v1/albums/16maAu5lqvFBSEEHyB5GzV',
#     'id': '16maAu5lqvFBSEEHyB5GzV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a8f5bb7820a39675e04f4aa8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a8f5bb7820a39675e04f4aa8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a8f5bb7820a39675e04f4aa8',
#       'width': 64}],
#     'name': 'Wild Side (feat. Cardi B)',
#     'release_date': '2021-07-22',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:16maAu5lqvFBSEEHyB5GzV'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cWZOOzeOm4WmBJRnD5R7I'},
#      'href': 'https://api.spotify.com/v1/artists/2cWZOOzeOm4WmBJRnD5R7I',
#      'id': '2cWZOOzeOm4WmBJRnD5R7I',
#      'name': 'Normani',
#      'type': 'artist',
#      'uri': 'spotify:artist:2cWZOOzeOm4WmBJRnD5R7I'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#      'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#      'id': '4kYSro6naA4h99UJvo89HB',
#      'name': 'Cardi B',
#      'type': 'artist',
#      'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'}],
#    'disc_number': 1,
#    'duration_ms': 209476,
#    'explicit': True,
#    'external_ids': {'isrc': 'USRC12101473'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2vXgyN14LX2zl7JEASw242'},
#    'href': 'https://api.spotify.com/v1/tracks/2vXgyN14LX2zl7JEASw242',
#    'id': '2vXgyN14LX2zl7JEASw242',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Wild Side (feat. Cardi B)',
#    'popularity': 72,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e73219392fb13dda4d6e5054833b2c37f2b44195?cid=cd9cd1ff2710474993b146e14b5e2612',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2vXgyN14LX2zl7JEASw242'}]}

# %% [markdown]
# Outro dicionário complexo... Novamente, tentemos trata-lo utilizando `json_normalize()`

# %%
pd.json_normalize(top_10_tracks)
# Out:
#                                               tracks
# 0  [{'album': {'album_type': 'single', 'artists':...

# %% [markdown]
# Novamente, não é o resultado esperado...

# %%
top_10_tracks.keys()
# Out:
# dict_keys(['tracks'])

# %%
type(top_10_tracks['tracks'])
# Out:
# list

# %%
len(top_10_tracks['tracks'])
# Out:
# 10

# %%
top_10_tracks['tracks'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
top_10_tracks['tracks'][0]
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#     'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#     'id': '4kYSro6naA4h99UJvo89HB',
#     'name': 'Cardi B',
#     'type': 'artist',
#     'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#     'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#     'id': '5K4W6rqBFWDnAN6FQUkS6x',
#     'name': 'Kanye West',
#     'type': 'artist',
#     'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hcs9uc56yIGFCSy9leWe7'},
#     'href': 'https://api.spotify.com/v1/artists/3hcs9uc56yIGFCSy9leWe7',
#     'id': '3hcs9uc56yIGFCSy9leWe7',
#     'name': 'Lil Durk',
#     'type': 'artist',
#     'uri': 'spotify:artist:3hcs9uc56yIGFCSy9leWe7'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2qTIltFPwJzsyssGeOwdRO'},
#   'href': 'https://api.spotify.com/v1/albums/2qTIltFPwJzsyssGeOwdRO',
#   'id': '2qTIltFPwJzsyssGeOwdRO',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b629e669238964a725937c1b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b629e669238964a725937c1b',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b629e669238964a725937c1b',
#     'width': 64}],
#   'name': 'Hot Shit (feat. Ye & Lil Durk)',
#   'release_date': '2022-07-01',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:2qTIltFPwJzsyssGeOwdRO'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#    'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#    'id': '4kYSro6naA4h99UJvo89HB',
#    'name': 'Cardi B',
#    'type': 'artist',
#    'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#    'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#    'id': '5K4W6rqBFWDnAN6FQUkS6x',
#    'name': 'Kanye West',
#    'type': 'artist',
#    'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hcs9uc56yIGFCSy9leWe7'},
#    'href': 'https://api.spotify.com/v1/artists/3hcs9uc56yIGFCSy9leWe7',
#    'id': '3hcs9uc56yIGFCSy9leWe7',
#    'name': 'Lil Durk',
#    'type': 'artist',
#    'uri': 'spotify:artist:3hcs9uc56yIGFCSy9leWe7'}],
#  'disc_number': 1,
#  'duration_ms': 211649,
#  'explicit': True,
#  'external_ids': {'isrc': 'USAT22208514'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/3uJFmluXzYedoJcvhpC1AW'},
#  'href': 'https://api.spotify.com/v1/tracks/3uJFmluXzYedoJcvhpC1AW',
#  'id': '3uJFmluXzYedoJcvhpC1AW',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Hot Shit (feat. Ye & Lil Durk)',
#  'popularity': 81,
#  'preview_url': 'https://p.scdn.co/mp3-preview/3b7bb38fd34d6cc497b18456924866c558626d79?cid=cd9cd1ff2710474993b146e14b5e2612',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:3uJFmluXzYedoJcvhpC1AW'}

# %%
[track['name'] for track in top_10_tracks['tracks']]
# Out:
# ['Hot Shit (feat. Ye & Lil Durk)',
#  'WAP (feat. Megan Thee Stallion)',
#  'I Like It',
#  'South of the Border (feat. Camila Cabello & Cardi B)',
#  'Rumors (feat. Cardi B)',
#  'Finesse - Remix; feat. Cardi B',
#  'Up',
#  'Please Me',
#  'Shake It (feat. Cardi B, Dougie B & Bory300)',
#  'Wild Side (feat. Cardi B)']

# %%
[track['uri'] for track in top_10_tracks['tracks']]
# Out:
# ['spotify:track:3uJFmluXzYedoJcvhpC1AW',
#  'spotify:track:4Oun2ylbjFKMPTiaSbbCih',
#  'spotify:track:58q2HKrzhC3ozto2nDdN4z',
#  'spotify:track:4vUmTMuQqjdnvlZmAH61Qk',
#  'spotify:track:6KgtcmCF9Ky68XC7ezxl3s',
#  'spotify:track:3Vo4wInECJQuz9BIBMOu8i',
#  'spotify:track:1M4OcYkxAtu3ErzSgDEfoi',
#  'spotify:track:0PG9fbaaHFHfre2gUVo7AN',
#  'spotify:track:0RkCnqwF8Tfl2QGPZwopyk',
#  'spotify:track:2vXgyN14LX2zl7JEASw242']

# %%
top10_cardib_uri = [track['uri'] for track in top_10_tracks['tracks']]

# %%
top10_cardib_uri
# Out:
# ['spotify:track:3uJFmluXzYedoJcvhpC1AW',
#  'spotify:track:4Oun2ylbjFKMPTiaSbbCih',
#  'spotify:track:58q2HKrzhC3ozto2nDdN4z',
#  'spotify:track:4vUmTMuQqjdnvlZmAH61Qk',
#  'spotify:track:6KgtcmCF9Ky68XC7ezxl3s',
#  'spotify:track:3Vo4wInECJQuz9BIBMOu8i',
#  'spotify:track:1M4OcYkxAtu3ErzSgDEfoi',
#  'spotify:track:0PG9fbaaHFHfre2gUVo7AN',
#  'spotify:track:0RkCnqwF8Tfl2QGPZwopyk',
#  'spotify:track:2vXgyN14LX2zl7JEASw242']

# %% [markdown]
# ### Extraindo Audio Features
#
# Agora, com o URI de cada uma das 10 maiores músicas de um artista, podemos utilizar o método `.audio_features()` para extrair os *audio features* de cada uma dessas músicas:

# %%
spotify.audio_features(top10_cardib_uri[3])
# Out:
# [{'danceability': 0.857,
#   'energy': 0.621,
#   'key': 9,
#   'loudness': -6.376,
#   'mode': 0,
#   'speechiness': 0.0825,
#   'acousticness': 0.148,
#   'instrumentalness': 0,
#   'liveness': 0.0865,
#   'valence': 0.668,
#   'tempo': 97.989,
#   'type': 'audio_features',
#   'id': '4vUmTMuQqjdnvlZmAH61Qk',
#   'uri': 'spotify:track:4vUmTMuQqjdnvlZmAH61Qk',
#   'track_href': 'https://api.spotify.com/v1/tracks/4vUmTMuQqjdnvlZmAH61Qk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4vUmTMuQqjdnvlZmAH61Qk',
#   'duration_ms': 204467,
#   'time_signature': 4}]

# %% [markdown]
# ## Construindo nosso DB
#
# Para construir um DB que possa responder nossa pergunta original, precisamos:
#
# 1. Consolidar os métodos que analisamos nas etapas anteriores;
# 1. Determinar quais **entidades** nosso banco representará;
# 1. Escrever o código para extrair as informações necessárias e carrega-la no DB.
#
# Podemos estruturar nosso DB ao longo de 3 tabelas:
#
# 1. **`headliner`**: tabela com a relação entre festivais e artistas;
# 1. **`artist`**: tabela com informação de artistas;
# 1. **`track`**: tabela com Audio Features (e outras informações de faixa).
#
# Antes de mais nada vamos nos conectar ao nosso DB:

# %%
import sqlalchemy as sa
load_dotenv('credentials/mysql.env')
url_banco = "localhost"
nome_db = "spotify"
conn_str = f"mysql+pymysql://root:sua_senha@{url_banco}/{nome_db}"
engine = sa.create_engine(conn_str)

tb_festivals.to_sql('fiifoofuu', engine, index = False, if_exists = 'replace')

# %% [markdown]
# ### Tabela `headliner`
#
# A tabela `headliner` deve conter as informações de quais artistas vão tocar em quais festivais. Poderíamos utilizar a tabela que carregamos do Google Sheets diretamente, mas isso faria o cruzamento entre **headliner** e **artist** pelo nome do artista (que pode ser frágil).
#
# Vamos utilizar a API do Spotify para enriquecer a nossa tabela original com os URIs de cada artista:

# %%
tb_festivals.head()
# Out:
#        festival                 headliners
# 0  Tomorrowland              Martin Garrix
# 1  Tomorrowland           Armin van Buuren
# 2  Tomorrowland  Dimitri Vegas & Like Mike
# 3  Tomorrowland                 Marshmello
# 4  Tomorrowland                Amelie Lens

# %%
array_headliner = tb_festivals['headliners'].unique()
array_headliner[0:10]
# Out:
# array(['Martin Garrix', 'Armin van Buuren', 'Dimitri Vegas & Like Mike',
#        'Marshmello', 'Amelie Lens', 'Adam Beyer', 'Eric Prydz', 'NERVO',
#        'Billie Eilish', 'Paul McCartney'], dtype=object)

# %%
dict_uri = dict()
for artista in array_headliner:
    search_result = spotify.search(q=artista, type="artist")
    dict_uri[artista] = search_result['artists']['items'][0]['uri']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [64], in <cell line: 2>()
#       2 for artista in array_headliner:
#       3     search_result = spotify.search(q=artista, type="artist")
# ----> 4     dict_uri[artista] = search_result['artists']['items'][0]['uri']
#
# IndexError: list index out of range

# %%
spotify.search(q=artista, type="artist")
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Fabio+%26+Grooverider+and+The+Outlook+Orchestra&type=artist&offset=0&limit=10',
#   'items': [],
#   'limit': 10,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0}}

# %%
dict_uri = dict()
for artista in array_headliner:
    try:
        search_result = spotify.search(q=artista, type="artist")
        dict_uri[artista] = search_result['artists']['items'][0]['uri']
    except IndexError as e:
        dict_uri[artista] = np.nan

# %%
dict_uri
# Out:
# {'Martin Garrix': 'spotify:artist:60d24wfXkVzDSfLS6hyCjZ',
#  'Armin van Buuren': 'spotify:artist:0SfsnGyD8FpIN4U4WCkBZ5',
#  'Dimitri Vegas & Like Mike': 'spotify:artist:73jBynjsVtofjRpdpRAJGk',
#  'Marshmello': 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T',
#  'Amelie Lens': 'spotify:artist:5Ho1vKl1Uz8bJlk4vbmvmf',
#  'Adam Beyer': 'spotify:artist:1btv9qmIpbp7q1ixCYNdHu',
#  'Eric Prydz': 'spotify:artist:5sm0jQ1mq0dusiLtDJ2b4R',
#  'NERVO': 'spotify:artist:4j5KBTO4tk7up54ZirNGvK',
#  'Billie Eilish': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH',
#  'Paul McCartney': 'spotify:artist:4STHEaNw4mPZ2tzheohgXB',
#  'Kendrick Lamar': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg',
#  'Diana Ross': 'spotify:artist:3MdG05syQeRYPPcClLaUGl',
#  'Burna Boy': 'spotify:artist:3wcj11K77LjEY1PkEazffa',
#  'Herbie Hancock': 'spotify:artist:2ZvrvbQNrHKwjT7qfGFFUW',
#  'Pet Shop Boys': 'spotify:artist:2ycnb8Er79LoH2AsR5ldjh',
#  'Lorde': 'spotify:artist:163tK9Wjr9P9DmM0AVK7lm',
#  'Metallica': 'spotify:artist:2ye2Wgw4gimLv2eAKyk1NB',
#  'The Killers': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu',
#  'Muse': 'spotify:artist:12Chz98pHFMPJEknJQMWvI',
#  'Kings of Leon': 'spotify:artist:2qk9voo8llSGYcZ6xrBzKx',
#  'twenty one pilots': 'spotify:artist:3YQKmKGau1PzlVlkL1iodx',
#  'Imagine Dragons': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q',
#  'Faith No More': 'spotify:artist:6GbCJZrI318Ybm8mY36Of5',
#  'Pixies': 'spotify:artist:6zvul52xwTWzilBZl6BUbT',
#  'Placebo': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB',
#  'David Guetta': 'spotify:artist:1Cs0zKBU1kc0i8ypK3B9
#  'Carl Cox': 'spotify:artist:19SmlbABtI4bXz864MLqOS'}

# %%
tb_festivals['artist_uri'] = tb_festivals['headliners'].map(dict_uri)
tb_festivals.head()
# Out:
#        festival                 headliners  \
# 0  Tomorrowland              Martin Garrix
# 1  Tomorrowland           Armin van Buuren
# 2  Tomorrowland  Dimitri Vegas & Like Mike
# 3  Tomorrowland                 Marshmello
# 4  Tomorrowland                Amelie Lens
#
#                               artist_uri
# 0  spotify:artist:60d24wfXkVzDSfLS6hyCjZ
# 1  spotify:artist:0SfsnGyD8FpIN4U4WCkBZ5
# 2  spotify:artist:73jBynjsVtofjRpdpRAJGk
# 3  spotify:artist:64KEffDW9EtZ1y2vBYgq8T
# 4  spotify:artist:5Ho1vKl1Uz8bJlk4vbmvmf

# %%
tb_festivals['headliners'].map(dict_uri)
# Out:
# 0      spotify:artist:60d24wfXkVzDSfLS6hyCjZ
# 1      spotify:artist:0SfsnGyD8FpIN4U4WCkBZ5
# 2      spotify:artist:73jBynjsVtofjRpdpRAJGk
# 3      spotify:artist:64KEffDW9EtZ1y2vBYgq8T
# 4      spotify:artist:5Ho1vKl1Uz8bJlk4vbmvmf
#                        ...
# 196    spotify:artist:60d24wfXkVzDSfLS6hyCjZ
# 197    spotify:artist:73A3bLnfnz5BoQjb4gNCga
# 198    spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z
# 199    spotify:artist:0CbeG1224FS58EUx4tPevZ
# 200    spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai
# Name: headliners, Length: 201, dtype: object

# %%
tb_festivals[tb_festivals['artist_uri'].isna()]
# Out:
#                      festival                                     headliners  \
# 116  Outlook Origins Festival  Fabio & Grooverider and The Outlook Orchestra
#
#     artist_uri
# 116        NaN

# %%
tb_festivals.dropna()
# Out:
#          festival                 headliners  \
# 0    Tomorrowland              Martin Garrix
# 1    Tomorrowland           Armin van Buuren
# 2    Tomorrowland  Dimitri Vegas & Like Mike
# 3    Tomorrowland                 Marshmello
# 4    Tomorrowland                Amelie Lens
# ..            ...                        ...
# 196   Creamfields              Martin Garrix
# 197   Creamfields                      Bicep
# 198   Creamfields                     Tiësto
# 199   Creamfields              Timmy Trumpet
# 200   Creamfields               David Guetta
#
#                                 artist_uri
# 0    spotify:artist:60d24wfXkVzDSfLS6hyCjZ
# 1    spotify:artist:0SfsnGyD8FpIN4U4WCkBZ5
# 2    spotify:artist:73jBynjsVtofjRpdpRAJGk
# 3    spotify:artist:64KEffDW9EtZ1y2vBYgq8T
# 4    spotify:artist:5Ho1vKl1Uz8bJlk4vbmvmf
# ..                                     ...
# 196  spotify:artist:60d24wfXkVzDSfLS6hyCjZ
# 197  spotify:artist:73A3bLnfnz5BoQjb4gNCga
# 198  spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z
# 199  spotify:artist:0CbeG1224FS58EUx4tPevZ
# 200  spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai
#
# [200 rows x 3 columns]

# %%
tb_festivals.to_sql('fiifoofuu', engine, index = False, if_exists = 'replace')
# Out:
# 200

# %% [markdown]
# ### Tabela `artist`
#
# A tabela `artist` deve conter informações dos artistas presentes na tabela `headliner`. Vamos começar selecionando apenas os URIs distintos da tabela `headliner`:

# %%
artist_uri = engine.execute('SELECT DISTINCT artist_uri FROM headliner').fetchall()
artist_uri
# Out:
# [('spotify:artist:60d24wfXkVzDSfLS6hyCjZ',),
#  ('spotify:artist:0SfsnGyD8FpIN4U4WCkBZ5',),
#  ('spotify:artist:73jBynjsVtofjRpdpRAJGk',),
#  ('spotify:artist:64KEffDW9EtZ1y2vBYgq8T',),
#  ('spotify:artist:5Ho1vKl1Uz8bJlk4vbmvmf',),
#  ('spotify:artist:1btv9qmIpbp7q1ixCYNdHu',),
#  ('spotify:artist:5sm0jQ1mq0dusiLtDJ2b4R',),
#  ('spotify:artist:4j5KBTO4tk7up54ZirNGvK',),
#  ('spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH',),
#  ('spotify:artist:4STHEaNw4mPZ2tzheohgXB',),
#  ('spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg',),
#  ('spotify:artist:3MdG05syQeRYPPcClLaUGl',),
#  ('spotify:artist:3wcj11K77LjEY1PkEazffa',),
#  ('spotify:artist:2ZvrvbQNrHKwjT7qfGFFUW',),
#  ('spotify:artist:2ycnb8Er79LoH2AsR5ldjh',),
#  ('spotify:artist:163tK9Wjr9P9DmM0AVK7lm',),
#  ('spotify:artist:2ye2Wgw4gimLv2eAKyk1NB',),
#  ('spotify:artist:0C0XlULifJtAgn6ZNCW2eu',),
#  ('spotify:artist:12Chz98pHFMPJEknJQMWvI',),
#  ('spotify:artist:2qk9voo8llSGYcZ6xrBzKx',),
#  ('spotify:artist:3YQKmKGau1PzlVlkL1iodx',),
#  ('spotify:artist:53XhwfbYqKCa1cC15pYq2q',),
#  ('spotify:artist:6GbCJZrI318Ybm8mY36Of5',),
#  ('spotify:artist:6zvul52xwTWzilBZl6BUbT',),
#  ('spotify:artist:6RZUqkomCmb8zCRqc9eznB',),
#  ('spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai',),
#  ('spotify:artist:5QySqc6yAFDx9m7fedFZmC',),
#  ('spotify:artist:0CbeG1224FS58EUx4tPevZ',),
#  ('spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z',),
#  ('spotify:artist:4D75GcNG95ebPtNvoNVXhz',),
#  ('spotify:artist:5ChF3i92IPZHduM7jN3dpg',),
#  ('spotify:artist:0u6GtibW46tFX7koQ6uNJZ',),
#  ('spotify:artist:3tVQdUvClmAT7URs9V3rsp',),
#  ('spotify:artist:181bsRPaVXVlUKXrxwZfHK',),
#  ('spotify:artist:7bXgB6jMjp9ATFy66eO08Z',),
#  ('spotify:artist:0Y3agQaa6g2r0YmHPOO9rh',),
#  ('spotify:artist:4L3GTE04bW5N7azA9QPhjA',),
#  ('spotify:artist:1gWjcmBsveEYMxOZ0VRi32',),
#  ('spotify:artist:687cZJR45JO7jhk1LHIbgq',),
#  ('spotify:artist:62DmErcU7dqZbJaDqwsqzR',),
#  ('spotify:artist:3AA28KZvwAUcZuOKwyblJQ',),
#  ('spotify:artist:5INjqkS1o8h1imAzPqGZBb',),
#  ('spotify:artist:0dmPX6ovclgOy8WWJaFEUU',),
#  ('spotify:artist:1GhPHrq36VKCY3ucVaZCfo',),
#  ('spotify:artist:4UXJsSlnKd7ltsrHebV79Q',),
#  ('spotify:artist:6nS5roXSAGhTGr34W6n7Et',),
#  ('spotify:artist:2cCUtGK9sDU2EoElnk0GNB',),
#  ('spotify:artist:73jBynjsVtofjRpdpRAJGk',
#   'Dimitri Vegas & Like Mike',
#   70,
#   3256496),
#  ('spotify:artist:64KEffDW9EtZ1y2vBYgq8T', 'Marshmello', 82, 34151481),
#  ('spotify:artist:5Ho1vKl1Uz8bJlk4vbmvmf', 'Amelie Lens', 48, 454443)]

# %%
dados_artista[0]
# Out:
# ('spotify:artist:60d24wfXkVzDSfLS6hyCjZ', 'Martin Garrix', 76, 15618020)

# %%
tb_artista = pd.DataFrame(dados_artista, 
                          columns = ['artist_uri', 'artist_name', 'popularity', 'followers'])
tb_artista.head()
# Out:
#                               artist_uri                artist_name  \
# 0  spotify:artist:60d24wfXkVzDSfLS6hyCjZ              Martin Garrix
# 1  spotify:artist:0SfsnGyD8FpIN4U4WCkBZ5           Armin van Buuren
# 2  spotify:artist:73jBynjsVtofjRpdpRAJGk  Dimitri Vegas & Like Mike
# 3  spotify:artist:64KEffDW9EtZ1y2vBYgq8T                 Marshmello
# 4  spotify:artist:5Ho1vKl1Uz8bJlk4vbmvmf                Amelie Lens
#
#    popularity  followers
# 0          76   15618020
# 1          73    4179784
# 2          70    3256496
# 3          82   34151481
# 4          48     454443

# %%
tb_artista.to_sql('artist', engine, index = False, if_exists = 'replace')
# Out:
# 143

# %% [markdown]
# ### Tabela `tracks`
#
# Agora, com os URIs de cada artista, podemos utilizar os métodos `.artist_top_tracks()` e `.audio_features()` para extrair as informações de cada faixa (tanto informações gerais, como o nome, quanto os *audio features* em si):

# %%
top_10_tracks = spotify.artist_top_tracks('spotify:artist:0C0XlULifJtAgn6ZNCW2eu')
top_10_tracks
# Out:
# {'tracks': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#       'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#       'id': '0C0XlULifJtAgn6ZNCW2eu',
#       'name': 'The Killers',
#       'type': 'artist',
#       'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4piJq7R3gjUOxnYs6lDCTg'},
#     'href': 'https://api.spotify.com/v1/albums/4piJq7R3gjUOxnYs6lDCTg',
#     'id': '4piJq7R3gjUOxnYs6lDCTg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ccdddd46119a4ff53eaf1f5d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ccdddd46119a4ff53eaf1f5d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ccdddd46119a4ff53eaf1f5d',
#       'width': 64}],
#     'name': 'Hot Fuss',
#     'release_date': '2004',
#     'release_date_precision': 'year',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:4piJq7R3gjUOxnYs6lDCTg'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'disc_number': 1,
#    'duration_ms': 222973,
#    'explicit': False,
#    'external_ids': {'isrc': 'USIR20400274'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/003vvx7Niy0yvhvHt4a68B'},
#    'href': 'https://api.spotify.com/v1/tracks/003vvx7Niy0yvhvHt4a68B',
#    'id': '003vvx7Niy0yvhvHt4a68B',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Mr. Brightside',
#    'popularity': 86,
#    'preview_url': None,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:003vvx7Niy0yvhvHt4a68B'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#       'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#       'id': '0C0XlULifJtAgn6ZNCW2eu',
#       'name': 'The Killers',
#       'type': 'artist',
#       'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4piJq7R3gjUOxnYs6lDCTg'},
#     'href': 'https://api.spotify.com/v1/albums/4piJq7R3gjUOxnYs6lDCTg',
#     'id': '4piJq7R3gjUOxnYs6lDCTg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ccdddd46119a4ff53eaf1f5d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ccdddd46119a4ff53eaf1f5d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ccdddd46119a4ff53eaf1f5d',
#       'width': 64}],
#     'name': 'Hot Fuss',
#     'release_date': '2004',
#     'release_date_precision': 'year',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:4piJq7R3gjUOxnYs6lDCTg'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'disc_number': 1,
#    'duration_ms': 197200,
#    'explicit': False,
#    'external_ids': {'isrc': 'USIR20400195'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6PwjJ58I4t7Mae9xfZ9l9v'},
#    'href': 'https://api.spotify.com/v1/tracks/6PwjJ58I4t7Mae9xfZ9l9v',
#    'id': '6PwjJ58I4t7Mae9xfZ9l9v',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Somebody Told Me',
#    'popularity': 77,
#    'preview_url': None,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:6PwjJ58I4t7Mae9xfZ9l9v'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#       'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#       'id': '0C0XlULifJtAgn6ZNCW2eu',
#       'name': 'The Killers',
#       'type': 'artist',
#       'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4o3RJndRhHxkieQzQGhmbw'},
#     'href': 'https://api.spotify.com/v1/albums/4o3RJndRhHxkieQzQGhmbw',
#     'id': '4o3RJndRhHxkieQzQGhmbw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734f87f14089217e3f70a5f39e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024f87f14089217e3f70a5f39e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514f87f14089217e3f70a5f39e',
#       'width': 64}],
#     'name': "Sam's Town",
#     'release_date': '2006-09-27',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:4o3RJndRhHxkieQzQGhmbw'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'disc_number': 1,
#    'duration_ms': 220426,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM70605164'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/70wYA8oYHoMzhRRkARoMhU'},
#    'href': 'https://api.spotify.com/v1/tracks/70wYA8oYHoMzhRRkARoMhU',
#    'id': '70wYA8oYHoMzhRRkARoMhU',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'When You Were Young',
#    'popularity': 76,
#    'preview_url': None,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:70wYA8oYHoMzhRRkARoMhU'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#       'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#       'id': '0C0XlULifJtAgn6ZNCW2eu',
#       'name': 'The Killers',
#       'type': 'artist',
#       'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0Ug5scDXUIgGN8yanDBLQw'},
#     'href': 'https://api.spotify.com/v1/albums/0Ug5scDXUIgGN8yanDBLQw',
#     'id': '0Ug5scDXUIgGN8yanDBLQw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a43cd43ef4f3b2d5413b17f9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a43cd43ef4f3b2d5413b17f9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a43cd43ef4f3b2d5413b17f9',
#       'width': 64}],
#     'name': 'Day & Age (Bonus Tracks)',
#     'release_date': '2008-11-18',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0Ug5scDXUIgGN8yanDBLQw'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'disc_number': 1,
#    'duration_ms': 245373,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM70837367'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1sTsuZTdANkiFd7T34H3nb'},
#    'href': 'https://api.spotify.com/v1/tracks/1sTsuZTdANkiFd7T34H3nb',
#    'id': '1sTsuZTdANkiFd7T34H3nb',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Human',
#    'popularity': 75,
#    'preview_url': None,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:1sTsuZTdANkiFd7T34H3nb'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#       'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#       'id': '0C0XlULifJtAgn6ZNCW2eu',
#       'name': 'The Killers',
#       'type': 'artist',
#       'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4piJq7R3gjUOxnYs6lDCTg'},
#     'href': 'https://api.spotify.com/v1/albums/4piJq7R3gjUOxnYs6lDCTg',
#     'id': '4piJq7R3gjUOxnYs6lDCTg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ccdddd46119a4ff53eaf1f5d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ccdddd46119a4ff53eaf1f5d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ccdddd46119a4ff53eaf1f5d',
#       'width': 64}],
#     'name': 'Hot Fuss',
#     'release_date': '2004',
#     'release_date_precision': 'year',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:4piJq7R3gjUOxnYs6lDCTg'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'disc_number': 1,
#    'duration_ms': 301866,
#    'explicit': False,
#    'external_ids': {'isrc': 'USIR20400269'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5vollujufHY0jMZxx77VWr'},
#    'href': 'https://api.spotify.com/v1/tracks/5vollujufHY0jMZxx77VWr',
#    'id': '5vollujufHY0jMZxx77VWr',
#    'is_local': False,
#    'is_playable': True,
#    'name': "All These Things That I've Done",
#    'popularity': 72,
#    'preview_url': None,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:5vollujufHY0jMZxx77VWr'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#       'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#       'id': '0C0XlULifJtAgn6ZNCW2eu',
#       'name': 'The Killers',
#       'type': 'artist',
#       'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7ddxzwtg0QQj9kXYK29rpG'},
#     'href': 'https://api.spotify.com/v1/albums/7ddxzwtg0QQj9kXYK29rpG',
#     'id': '7ddxzwtg0QQj9kXYK29rpG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ece8b168e1daa086c53b447b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ece8b168e1daa086c53b447b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ece8b168e1daa086c53b447b',
#       'width': 64}],
#     'name': 'boy',
#     'release_date': '2022-08-05',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7ddxzwtg0QQj9kXYK29rpG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'disc_number': 1,
#    'duration_ms': 198480,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG12204694'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3Qw0WuniULBdYjXe2jsqCy'},
#    'href': 'https://api.spotify.com/v1/tracks/3Qw0WuniULBdYjXe2jsqCy',
#    'id': '3Qw0WuniULBdYjXe2jsqCy',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'boy',
#    'popularity': 71,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3Qw0WuniULBdYjXe2jsqCy'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#       'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#       'id': '0C0XlULifJtAgn6ZNCW2eu',
#       'name': 'The Killers',
#       'type': 'artist',
#       'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4o3RJndRhHxkieQzQGhmbw'},
#     'href': 'https://api.spotify.com/v1/albums/4o3RJndRhHxkieQzQGhmbw',
#     'id': '4o3RJndRhHxkieQzQGhmbw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734f87f14089217e3f70a5f39e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024f87f14089217e3f70a5f39e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514f87f14089217e3f70a5f39e',
#       'width': 64}],
#     'name': "Sam's Town",
#     'release_date': '2006-09-27',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:4o3RJndRhHxkieQzQGhmbw'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'disc_number': 1,
#    'duration_ms': 246840,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM70605406'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7cX4PJz1old9fyFI8RlfgW'},
#    'href': 'https://api.spotify.com/v1/tracks/7cX4PJz1old9fyFI8RlfgW',
#    'id': '7cX4PJz1old9fyFI8RlfgW',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Read My Mind',
#    'popularity': 70,
#    'preview_url': None,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:7cX4PJz1old9fyFI8RlfgW'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#       'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#       'id': '0C0XlULifJtAgn6ZNCW2eu',
#       'name': 'The Killers',
#       'type': 'artist',
#       'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4piJq7R3gjUOxnYs6lDCTg'},
#     'href': 'https://api.spotify.com/v1/albums/4piJq7R3gjUOxnYs6lDCTg',
#     'id': '4piJq7R3gjUOxnYs6lDCTg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ccdddd46119a4ff53eaf1f5d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ccdddd46119a4ff53eaf1f5d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ccdddd46119a4ff53eaf1f5d',
#       'width': 64}],
#     'name': 'Hot Fuss',
#     'release_date': '2004',
#     'release_date_precision': 'year',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:4piJq7R3gjUOxnYs6lDCTg'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'disc_number': 1,
#    'duration_ms': 234106,
#    'explicit': False,
#    'external_ids': {'isrc': 'USIR20400275'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3KANrKOFYyAxfjQJHkgBdb'},
#    'href': 'https://api.spotify.com/v1/tracks/3KANrKOFYyAxfjQJHkgBdb',
#    'id': '3KANrKOFYyAxfjQJHkgBdb',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Smile Like You Mean It',
#    'popularity': 67,
#    'preview_url': None,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:3KANrKOFYyAxfjQJHkgBdb'},
#   {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#       'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#       'id': '0C0XlULifJtAgn6ZNCW2eu',
#       'name': 'The Killers',
#       'type': 'artist',
#       'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3T5bbO2BOnnjun6jKhJdjV'},
#     'href': 'https://api.spotify.com/v1/albums/3T5bbO2BOnnjun6jKhJdjV',
#     'id': '3T5bbO2BOnnjun6jKhJdjV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27348488c2eee5727efc30bf657',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0248488c2eee5727efc30bf657',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485148488c2eee5727efc30bf657',
#       'width': 64}],
#     'name': 'Direct Hits',
#     'release_date': '2013-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:3T5bbO2BOnnjun6jKhJdjV'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'disc_number': 1,
#    'duration_ms': 242506,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71311841'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2aZ2Co4NeQRsqWcU930zHT'},
#    'href': 'https://api.spotify.com/v1/tracks/2aZ2Co4NeQRsqWcU930zHT',
#    'id': '2aZ2Co4NeQRsqWcU930zHT',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Shot At The Night',
#    'popularity': 66,
#    'preview_url': None,
#    'track_number': 14,
#    'type': 'track',
#    'uri': 'spotify:track:2aZ2Co4NeQRsqWcU930zHT'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#       'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#       'id': '0C0XlULifJtAgn6ZNCW2eu',
#       'name': 'The Killers',
#       'type': 'artist',
#       'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/72ZfMxLCPG8mlWC0TXfZQi'},
#     'href': 'https://api.spotify.com/v1/albums/72ZfMxLCPG8mlWC0TXfZQi',
#     'id': '72ZfMxLCPG8mlWC0TXfZQi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f65523eab3152dcca83b6fca',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f65523eab3152dcca83b6fca',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f65523eab3152dcca83b6fca',
#       'width': 64}],
#     'name': 'Wonderful Wonderful',
#     'release_date': '2017-09-22',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:72ZfMxLCPG8mlWC0TXfZQi'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'disc_number': 1,
#    'duration_ms': 250093,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71705733'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5aWhs651KYM26HYM16kRdk'},
#    'href': 'https://api.spotify.com/v1/tracks/5aWhs651KYM26HYM16kRdk',
#    'id': '5aWhs651KYM26HYM16kRdk',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'The Man',
#    'popularity': 64,
#    'preview_url': None,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:5aWhs651KYM26HYM16kRdk'}]}

# %%
top_10_tracks['tracks']
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4piJq7R3gjUOxnYs6lDCTg'},
#    'href': 'https://api.spotify.com/v1/albums/4piJq7R3gjUOxnYs6lDCTg',
#    'id': '4piJq7R3gjUOxnYs6lDCTg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273ccdddd46119a4ff53eaf1f5d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02ccdddd46119a4ff53eaf1f5d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851ccdddd46119a4ff53eaf1f5d',
#      'width': 64}],
#    'name': 'Hot Fuss',
#    'release_date': '2004',
#    'release_date_precision': 'year',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:4piJq7R3gjUOxnYs6lDCTg'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#     'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#     'id': '0C0XlULifJtAgn6ZNCW2eu',
#     'name': 'The Killers',
#     'type': 'artist',
#     'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#   'disc_number': 1,
#   'duration_ms': 222973,
#   'explicit': False,
#   'external_ids': {'isrc': 'USIR20400274'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/003vvx7Niy0yvhvHt4a68B'},
#   'href': 'https://api.spotify.com/v1/tracks/003vvx7Niy0yvhvHt4a68B',
#   'id': '003vvx7Niy0yvhvHt4a68B',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Mr. Brightside',
#   'popularity': 86,
#   'preview_url': None,
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:003vvx7Niy0yvhvHt4a68B'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4piJq7R3gjUOxnYs6lDCTg'},
#    'href': 'https://api.spotify.com/v1/albums/4piJq7R3gjUOxnYs6lDCTg',
#    'id': '4piJq7R3gjUOxnYs6lDCTg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273ccdddd46119a4ff53eaf1f5d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02ccdddd46119a4ff53eaf1f5d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851ccdddd46119a4ff53eaf1f5d',
#      'width': 64}],
#    'name': 'Hot Fuss',
#    'release_date': '2004',
#    'release_date_precision': 'year',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:4piJq7R3gjUOxnYs6lDCTg'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#     'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#     'id': '0C0XlULifJtAgn6ZNCW2eu',
#     'name': 'The Killers',
#     'type': 'artist',
#     'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#   'disc_number': 1,
#   'duration_ms': 197200,
#   'explicit': False,
#   'external_ids': {'isrc': 'USIR20400195'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6PwjJ58I4t7Mae9xfZ9l9v'},
#   'href': 'https://api.spotify.com/v1/tracks/6PwjJ58I4t7Mae9xfZ9l9v',
#   'id': '6PwjJ58I4t7Mae9xfZ9l9v',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Somebody Told Me',
#   'popularity': 77,
#   'preview_url': None,
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:6PwjJ58I4t7Mae9xfZ9l9v'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4o3RJndRhHxkieQzQGhmbw'},
#    'href': 'https://api.spotify.com/v1/albums/4o3RJndRhHxkieQzQGhmbw',
#    'id': '4o3RJndRhHxkieQzQGhmbw',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734f87f14089217e3f70a5f39e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024f87f14089217e3f70a5f39e',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514f87f14089217e3f70a5f39e',
#      'width': 64}],
#    'name': "Sam's Town",
#    'release_date': '2006-09-27',
#    'release_date_precision': 'day',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:4o3RJndRhHxkieQzQGhmbw'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#     'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#     'id': '0C0XlULifJtAgn6ZNCW2eu',
#     'name': 'The Killers',
#     'type': 'artist',
#     'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#   'disc_number': 1,
#   'duration_ms': 220426,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM70605164'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/70wYA8oYHoMzhRRkARoMhU'},
#   'href': 'https://api.spotify.com/v1/tracks/70wYA8oYHoMzhRRkARoMhU',
#   'id': '70wYA8oYHoMzhRRkARoMhU',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'When You Were Young',
#   'popularity': 76,
#   'preview_url': None,
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:70wYA8oYHoMzhRRkARoMhU'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0Ug5scDXUIgGN8yanDBLQw'},
#    'href': 'https://api.spotify.com/v1/albums/0Ug5scDXUIgGN8yanDBLQw',
#    'id': '0Ug5scDXUIgGN8yanDBLQw',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a43cd43ef4f3b2d5413b17f9',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a43cd43ef4f3b2d5413b17f9',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851a43cd43ef4f3b2d5413b17f9',
#      'width': 64}],
#    'name': 'Day & Age (Bonus Tracks)',
#    'release_date': '2008-11-18',
#    'release_date_precision': 'day',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:0Ug5scDXUIgGN8yanDBLQw'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#     'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#     'id': '0C0XlULifJtAgn6ZNCW2eu',
#     'name': 'The Killers',
#     'type': 'artist',
#     'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#   'disc_number': 1,
#   'duration_ms': 245373,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM70837367'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1sTsuZTdANkiFd7T34H3nb'},
#   'href': 'https://api.spotify.com/v1/tracks/1sTsuZTdANkiFd7T34H3nb',
#   'id': '1sTsuZTdANkiFd7T34H3nb',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Human',
#   'popularity': 75,
#   'preview_url': None,
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:1sTsuZTdANkiFd7T34H3nb'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4piJq7R3gjUOxnYs6lDCTg'},
#    'href': 'https://api.spotify.com/v1/albums/4piJq7R3gjUOxnYs6lDCTg',
#    'id': '4piJq7R3gjUOxnYs6lDCTg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273ccdddd46119a4ff53eaf1f5d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02ccdddd46119a4ff53eaf1f5d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851ccdddd46119a4ff53eaf1f5d',
#      'width': 64}],
#    'name': 'Hot Fuss',
#    'release_date': '2004',
#    'release_date_precision': 'year',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:4piJq7R3gjUOxnYs6lDCTg'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#     'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#     'id': '0C0XlULifJtAgn6ZNCW2eu',
#     'name': 'The Killers',
#     'type': 'artist',
#     'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#   'disc_number': 1,
#   'duration_ms': 301866,
#   'explicit': False,
#   'external_ids': {'isrc': 'USIR20400269'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5vollujufHY0jMZxx77VWr'},
#   'href': 'https://api.spotify.com/v1/tracks/5vollujufHY0jMZxx77VWr',
#   'id': '5vollujufHY0jMZxx77VWr',
#   'is_local': False,
#   'is_playable': True,
#   'name': "All These Things That I've Done",
#   'popularity': 72,
#   'preview_url': None,
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:5vollujufHY0jMZxx77VWr'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7ddxzwtg0QQj9kXYK29rpG'},
#    'href': 'https://api.spotify.com/v1/albums/7ddxzwtg0QQj9kXYK29rpG',
#    'id': '7ddxzwtg0QQj9kXYK29rpG',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273ece8b168e1daa086c53b447b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02ece8b168e1daa086c53b447b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851ece8b168e1daa086c53b447b',
#      'width': 64}],
#    'name': 'boy',
#    'release_date': '2022-08-05',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:7ddxzwtg0QQj9kXYK29rpG'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#     'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#     'id': '0C0XlULifJtAgn6ZNCW2eu',
#     'name': 'The Killers',
#     'type': 'artist',
#     'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#   'disc_number': 1,
#   'duration_ms': 198480,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUG12204694'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3Qw0WuniULBdYjXe2jsqCy'},
#   'href': 'https://api.spotify.com/v1/tracks/3Qw0WuniULBdYjXe2jsqCy',
#   'id': '3Qw0WuniULBdYjXe2jsqCy',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'boy',
#   'popularity': 71,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:3Qw0WuniULBdYjXe2jsqCy'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4o3RJndRhHxkieQzQGhmbw'},
#    'href': 'https://api.spotify.com/v1/albums/4o3RJndRhHxkieQzQGhmbw',
#    'id': '4o3RJndRhHxkieQzQGhmbw',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734f87f14089217e3f70a5f39e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024f87f14089217e3f70a5f39e',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514f87f14089217e3f70a5f39e',
#      'width': 64}],
#    'name': "Sam's Town",
#    'release_date': '2006-09-27',
#    'release_date_precision': 'day',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:4o3RJndRhHxkieQzQGhmbw'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#     'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#     'id': '0C0XlULifJtAgn6ZNCW2eu',
#     'name': 'The Killers',
#     'type': 'artist',
#     'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#   'disc_number': 1,
#   'duration_ms': 246840,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM70605406'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7cX4PJz1old9fyFI8RlfgW'},
#   'href': 'https://api.spotify.com/v1/tracks/7cX4PJz1old9fyFI8RlfgW',
#   'id': '7cX4PJz1old9fyFI8RlfgW',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Read My Mind',
#   'popularity': 70,
#   'preview_url': None,
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:7cX4PJz1old9fyFI8RlfgW'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4piJq7R3gjUOxnYs6lDCTg'},
#    'href': 'https://api.spotify.com/v1/albums/4piJq7R3gjUOxnYs6lDCTg',
#    'id': '4piJq7R3gjUOxnYs6lDCTg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273ccdddd46119a4ff53eaf1f5d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02ccdddd46119a4ff53eaf1f5d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851ccdddd46119a4ff53eaf1f5d',
#      'width': 64}],
#    'name': 'Hot Fuss',
#    'release_date': '2004',
#    'release_date_precision': 'year',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:4piJq7R3gjUOxnYs6lDCTg'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#     'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#     'id': '0C0XlULifJtAgn6ZNCW2eu',
#     'name': 'The Killers',
#     'type': 'artist',
#     'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#   'disc_number': 1,
#   'duration_ms': 234106,
#   'explicit': False,
#   'external_ids': {'isrc': 'USIR20400275'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3KANrKOFYyAxfjQJHkgBdb'},
#   'href': 'https://api.spotify.com/v1/tracks/3KANrKOFYyAxfjQJHkgBdb',
#   'id': '3KANrKOFYyAxfjQJHkgBdb',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Smile Like You Mean It',
#   'popularity': 67,
#   'preview_url': None,
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:3KANrKOFYyAxfjQJHkgBdb'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3T5bbO2BOnnjun6jKhJdjV'},
#    'href': 'https://api.spotify.com/v1/albums/3T5bbO2BOnnjun6jKhJdjV',
#    'id': '3T5bbO2BOnnjun6jKhJdjV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27348488c2eee5727efc30bf657',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0248488c2eee5727efc30bf657',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485148488c2eee5727efc30bf657',
#      'width': 64}],
#    'name': 'Direct Hits',
#    'release_date': '2013-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 18,
#    'type': 'album',
#    'uri': 'spotify:album:3T5bbO2BOnnjun6jKhJdjV'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#     'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#     'id': '0C0XlULifJtAgn6ZNCW2eu',
#     'name': 'The Killers',
#     'type': 'artist',
#     'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#   'disc_number': 1,
#   'duration_ms': 242506,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71311841'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2aZ2Co4NeQRsqWcU930zHT'},
#   'href': 'https://api.spotify.com/v1/tracks/2aZ2Co4NeQRsqWcU930zHT',
#   'id': '2aZ2Co4NeQRsqWcU930zHT',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Shot At The Night',
#   'popularity': 66,
#   'preview_url': None,
#   'track_number': 14,
#   'type': 'track',
#   'uri': 'spotify:track:2aZ2Co4NeQRsqWcU930zHT'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#      'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#      'id': '0C0XlULifJtAgn6ZNCW2eu',
#      'name': 'The Killers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/72ZfMxLCPG8mlWC0TXfZQi'},
#    'href': 'https://api.spotify.com/v1/albums/72ZfMxLCPG8mlWC0TXfZQi',
#    'id': '72ZfMxLCPG8mlWC0TXfZQi',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f65523eab3152dcca83b6fca',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f65523eab3152dcca83b6fca',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f65523eab3152dcca83b6fca',
#      'width': 64}],
#    'name': 'Wonderful Wonderful',
#    'release_date': '2017-09-22',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:72ZfMxLCPG8mlWC0TXfZQi'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#     'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#     'id': '0C0XlULifJtAgn6ZNCW2eu',
#     'name': 'The Killers',
#     'type': 'artist',
#     'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#   'disc_number': 1,
#   'duration_ms': 250093,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71705733'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5aWhs651KYM26HYM16kRdk'},
#   'href': 'https://api.spotify.com/v1/tracks/5aWhs651KYM26HYM16kRdk',
#   'id': '5aWhs651KYM26HYM16kRdk',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'The Man',
#   'popularity': 64,
#   'preview_url': None,
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:5aWhs651KYM26HYM16kRdk'}]

# %%
[track['uri'] for track in top_10_tracks['tracks']]
# Out:
# ['spotify:track:003vvx7Niy0yvhvHt4a68B',
#  'spotify:track:6PwjJ58I4t7Mae9xfZ9l9v',
#  'spotify:track:70wYA8oYHoMzhRRkARoMhU',
#  'spotify:track:1sTsuZTdANkiFd7T34H3nb',
#  'spotify:track:5vollujufHY0jMZxx77VWr',
#  'spotify:track:3Qw0WuniULBdYjXe2jsqCy',
#  'spotify:track:7cX4PJz1old9fyFI8RlfgW',
#  'spotify:track:3KANrKOFYyAxfjQJHkgBdb',
#  'spotify:track:2aZ2Co4NeQRsqWcU930zHT',
#  'spotify:track:5aWhs651KYM26HYM16kRdk']

# %%
top_10_tracks['tracks'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
top_10_tracks['tracks'][0]['name']
# Out:
# 'Mr. Brightside'

# %%
spotify.audio_features(top_10_tracks['tracks'][0]['uri'])
# Out:
# [{'danceability': 0.352,
#   'energy': 0.911,
#   'key': 1,
#   'loudness': -5.23,
#   'mode': 1,
#   'speechiness': 0.0747,
#   'acousticness': 0.00121,
#   'instrumentalness': 0,
#   'liveness': 0.0995,
#   'valence': 0.236,
#   'tempo': 148.033,
#   'type': 'audio_features',
#   'id': '003vvx7Niy0yvhvHt4a68B',
#   'uri': 'spotify:track:003vvx7Niy0yvhvHt4a68B',
#   'track_href': 'https://api.spotify.com/v1/tracks/003vvx7Niy0yvhvHt4a68B',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/003vvx7Niy0yvhvHt4a68B',
#   'duration_ms': 222973,
#   'time_signature': 4}]

# %%
track_data = []

for artist in artist_uri:
    top_tracks = spotify.artist_top_tracks(artist[0])
    for track in top_tracks['tracks']:
        track_au = spotify.audio_features(track['uri'])[0]
        track_au['name'] = track['name']
        track_au['popularity'] = track['popularity']
        track_au['explicit'] = track['explicit']
        track_au['artist_uri'] = artist[0]
        track_data.append(track_au)

# %%
track
# Out:
# {'album': {'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6b439Wfa3J7VMZCTNoLgN8'},
#   'href': 'https://api.spotify.com/v1/albums/6b439Wfa3J7VMZCTNoLgN8',
#   'id': '6b439Wfa3J7VMZCTNoLgN8',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273db8fbd9b4acb3a967c3408e7',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02db8fbd9b4acb3a967c3408e7',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851db8fbd9b4acb3a967c3408e7',
#     'width': 64}],
#   'name': 'EDM Vegas 2017',
#   'release_date': '2017-06-16',
#   'release_date_precision': 'day',
#   'total_tracks': 29,
#   'type': 'album',
#   'uri': 'spotify:album:6b439Wfa3J7VMZCTNoLgN8'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3yDIp0kaq9EFKe07X1X2rz'},
#    'href': 'https://api.spotify.com/v1/artists/3yDIp0kaq9EFKe07X1X2rz',
#    'id': '3yDIp0kaq9EFKe07X1X2rz',
#    'name': 'Nile Rodgers',
#    'type': 'artist',
#    'uri': 'spotify:artist:3yDIp0kaq9EFKe07X1X2rz'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/19SmlbABtI4bXz864MLqOS'},
#    'href': 'https://api.spotify.com/v1/artists/19SmlbABtI4bXz864MLqOS',
#    'id': '19SmlbABtI4bXz864MLqOS',
#    'name': 'Carl Cox',
#    'type': 'artist',
#    'uri': 'spotify:artist:19SmlbABtI4bXz864MLqOS'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Mlrzwh665lRUOEV1ZWyWu'},
#    'href': 'https://api.spotify.com/v1/artists/7Mlrzwh665lRUOEV1ZWyWu',
#    'id': '7Mlrzwh665lRUOEV1ZWyWu',
#    'name': 'David Tort',
#    'type': 'artist',
#    'uri': 'spotify:artist:7Mlrzwh665lRUOEV1ZWyWu'}],
#  'disc_number': 1,
#  'duration_ms': 452282,
#  'explicit': False,
#  'external_ids': {'isrc': 'GBHAD1600175'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/2mrYurqSVRigZnrLZk42j4'},
#  'href': 'https://api.spotify.com/v1/tracks/2mrYurqSVRigZnrLZk42j4',
#  'id': '2mrYurqSVRigZnrLZk42j4',
#  'is_local': False,
#  'is_playable': True,
#  'name': "Ohh Baby - David Tort's Dub Tech Mix",
#  'popularity': 41,
#  'preview_url': 'https://p.scdn.co/mp3-preview/9827e546aadb0e62e559d5ec23fc8a98005f9fba?cid=cd9cd1ff2710474993b146e14b5e2612',
#  'track_number': 6,
#  'type': 'track',
#  'uri': 'spotify:track:2mrYurqSVRigZnrLZk42j4'}

# %%
spotify.audio_features(track['uri'])
# Out:
# [{'danceability': 0.732,
#   'energy': 0.941,
#   'key': 11,
#   'loudness': -6.817,
#   'mode': 0,
#   'speechiness': 0.127,
#   'acousticness': 0.00328,
#   'instrumentalness': 0.88,
#   'liveness': 0.0624,
#   'valence': 0.259,
#   'tempo': 124.006,
#   'type': 'audio_features',
#   'id': '2mrYurqSVRigZnrLZk42j4',
#   'uri': 'spotify:track:2mrYurqSVRigZnrLZk42j4',
#   'track_href': 'https://api.spotify.com/v1/tracks/2mrYurqSVRigZnrLZk42j4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2mrYurqSVRigZnrLZk42j4',
#   'duration_ms': 452283,
#   'time_signature': 4}]

# %%
abc = spotify.audio_features(track['uri'])[0]

# %%
abc['name'] = track['name']

# %%
abc
# Out:
# {'danceability': 0.732,
#  'energy': 0.941,
#  'key': 11,
#  'loudness': -6.817,
#  'mode': 0,
#  'speechiness': 0.127,
#  'acousticness': 0.00328,
#  'instrumentalness': 0.88,
#  'liveness': 0.0624,
#  'valence': 0.259,
#  'tempo': 124.006,
#  'type': 'audio_features',
#  'id': '2mrYurqSVRigZnrLZk42j4',
#  'uri': 'spotify:track:2mrYurqSVRigZnrLZk42j4',
#  'track_href': 'https://api.spotify.com/v1/tracks/2mrYurqSVRigZnrLZk42j4',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2mrYurqSVRigZnrLZk42j4',
#  'duration_ms': 452283,
#  'time_signature': 4,
#  'name': "Ohh Baby - David Tort's Dub Tech Mix"}

# %%
tb_tracks = pd.DataFrame(track_data)
tb_tracks.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.584   0.540    1    -7.786     0       0.0576        0.0895
# 1         0.501   0.519    4    -5.880     0       0.0409        0.1090
# 2         0.661   0.723    5    -6.976     0       0.0566        0.1790
# 3         0.414   0.486    6    -6.431     0       0.0311        0.0129
# 4         0.693   0.725    5    -6.318     0       0.0439        0.0628
#
#    instrumentalness  liveness  valence  ...                      id  \
# 0          0.000000     0.261    0.195  ...  3ebXMykcMXOcLeJ9xZ17XH
# 1          0.000000     0.454    0.168  ...  23L5CiUhw2jV1OIMwthR3S
# 2          0.000012     0.140    0.316  ...  7Feaw9WAEREY0DUOSXJLOM
# 3          0.000000     0.111    0.368  ...  4ut5G4rgB1ClpMTMfjoIuy
# 4          0.007850     0.157    0.379  ...  0lqgo6rIBS0nVsvppZC3Ay
#
#                                     uri  \
# 0  spotify:track:3ebXMykcMXOcLeJ9xZ17XH
# 1  spotify:track:23L5CiUhw2jV1OIMwthR3S
# 2  spotify:track:7Feaw9WAEREY0DUOSXJLOM
# 3  spotify:track:4ut5G4rgB1ClpMTMfjoIuy
# 4  spotify:track:0lqgo6rIBS0nVsvppZC3Ay
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3ebXMykcMXOc...
# 1  https://api.spotify.com/v1/tracks/23L5CiUhw2jV...
# 2  https://api.spotify.com/v1/tracks/7Feaw9WAEREY...
# 3  https://api.spotify.com/v1/tracks/4ut5G4rgB1Cl...
# 4  https://api.spotify.com/v1/tracks/0lqgo6rIBS0n...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3ebX...      220883
# 1  https://api.spotify.com/v1/audio-analysis/23L5...      195707
# 2  https://api.spotify.com/v1/audio-analysis/7Fea...      163805
# 3  https://api.spotify.com/v1/audio-analysis/4ut5...      230762
# 4  https://api.spotify.com/v1/audio-analysis/0lqg...      190560
#
#   time_signature                                               name  \
# 0              4                                Scared to Be Lonely
# 1              4                                In the Name of Love
# 2              4  Summer Days (feat. Macklemore & Patrick Stump ...
# 3              4                          High On Life (feat. Bonn)
# 4              4                                               Loop
#
#    popularity explicit                             artist_uri
# 0          77    False  spotify:artist:60d24wfXkVzDSfLS6hyCjZ
# 1          77    False  spotify:artist:60d24wfXkVzDSfLS6hyCjZ
# 2          75     True  spotify:artist:60d24wfXkVzDSfLS6hyCjZ
# 3          71    False  spotify:artist:60d24wfXkVzDSfLS6hyCjZ
# 4          70     True  spotify:artist:60d24wfXkVzDSfLS6hyCjZ
#
# [5 rows x 22 columns]

# %%
tb_tracks.to_sql('track', engine, index = False, if_exists = 'replace')
# Out:
# 1412

# %% [markdown]
# ## Usando nosso DB

# %%
query_festival = '''
    SELECT
        h.festival,
        AVG(t.valence) AS feliz,
        AVG(t.energy) AS energia,
        AVG(t.danceability) AS dancavel,
        AVG(a.popularity) AS pop,
        AVG(a.followers) AS seguidores
    FROM 
        headliner h JOIN
        artist a ON (h.artist_uri = a.artist_uri) JOIN
        track t ON (a.artist_uri = t.artist_uri)
    GROUP BY
        h.festival 
'''
tb_festival_au = pd.read_sql(query_festival, engine)
tb_festival_au.head()
# Out:
#         festival     feliz   energia  dancavel      pop    seguidores
# 0    Creamfields  0.355613  0.779050  0.673100  68.6250  6.666338e+06
# 1   Tomorrowland  0.336969  0.805462  0.643012  64.8750  7.398469e+06
# 2            AMF  0.413505  0.815963  0.634975  73.5000  5.354958e+06
# 3  SAGA Festival  0.415411  0.770862  0.691025  67.3750  7.061979e+06
# 4      Time Warp  0.264539  0.736357  0.708914  44.2857  3.130811e+05

# %%
tb_festival_au.sort_values('seguidores', ascending = False).head()
# Out:
#                  festival     feliz   energia  dancavel      pop    seguidores
# 13        Sziget Festival  0.596743  0.714929  0.621529  81.5714  2.175721e+07
# 5             Glastonbury  0.513408  0.581076  0.632138  73.6250  1.371096e+07
# 11      Mad Cool Festival  0.435000  0.764189  0.532622  74.5556  1.238846e+07
# 6       Wireless Festival  0.511045  0.643625  0.677313  80.2500  1.226670e+07
# 20  Rolling Loud Portugal  0.422218  0.608063  0.736450  81.6250  1.076807e+07

# %% [markdown]
# # Voltamos 21h28

# %%
a = '13,47%'

# %%
float(a.replace('%', '').replace('.', '').replace(',', '.'))
# Out:
# 0.13470000000000001

# %%
re.sub()

# %%
import pandas as pd

# %%
import numpy as np

# %%
abc = pd.DataFrame({'a' : [1, 1, 1, 2], 'b' : [1,2,3,1]})

# %%
np.unique(abc[['a', 'b']].values)
# Out:
# array([1, 2, 3])
