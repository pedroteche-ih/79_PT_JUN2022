# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Limpeza-de-dados" data-toc-modified-id="Limpeza-de-dados-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Limpeza de dados</a></span></li><li><span><a href="#EDA" data-toc-modified-id="EDA-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>EDA</a></span></li><li><span><a href="#Modelo-I" data-toc-modified-id="Modelo-I-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Modelo I</a></span></li><li><span><a href="#Modelo-II" data-toc-modified-id="Modelo-II-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Modelo II</a></span></li><li><span><a href="#Modelo-III" data-toc-modified-id="Modelo-III-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Modelo III</a></span></li><li><span><a href="#EDA-II" data-toc-modified-id="EDA-II-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>EDA II</a></span></li><li><span><a href="#Modelo-IV" data-toc-modified-id="Modelo-IV-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Modelo IV</a></span></li><li><span><a href="#Modelo-V---Partiu-ignorância..." data-toc-modified-id="Modelo-V---Partiu-ignorância...-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Modelo V - Partiu ignorância...</a></span></li></ul></div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import patsy
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import Normalizer
from sklearn.feature_selection import RFECV

# %% [markdown]
# # Limpeza de dados

# %% [markdown]
# Limpeza de 0s nas dimensões

# %%
diamonds = pd.read_csv('tb_diamantes.csv')
x_0 = diamonds['x'] == 0
y_0 = diamonds['y'] == 0
z_0 = diamonds['z'] == 0
dim_0 = x_0 | y_0 | z_0
diamonds_c = diamonds[~dim_0].copy()
print('Linhas na etapa atual:', str(len(diamonds_c)))
# Out:
# Linhas na etapa atual: 48922

# %%
dict_clarity = {
    'I1': 0,
    'SI2': 1,
    'SI1': 2,
    'VS2': 3,
    'VS1': 4,
    'VVS2': 5,
    'VVS1': 6,
    'IF': 7
}
diamonds_c['clarity_num'] = diamonds_c['clarity'].map(dict_clarity)

# %%
dict_color = {
    'D': 0,
    'E': 1,
    'F': 2,
    'G': 3,
    'H': 4,
    'I': 5,
    'J': 6,
}
diamonds_c['color_num'] = diamonds_c['color'].map(dict_color)

# %%
dict_cut = {
    'Fair': 0,
    'Good': 1,
    'Very Good': 2,
    'Premium': 3,
    'Ideal': 4,
}
diamonds_c['cut_num'] = diamonds_c['cut'].map(dict_cut)

# %% [markdown]
# Limpeza de outliers

# %%
diamonds_c['volume'] = diamonds_c['x'] * diamonds_c['y'] * diamonds_c['z']
diamonds_c['price_k'] = diamonds_c['price']/diamonds_c['carat']
diamonds_c['density'] = diamonds_c['carat']/diamonds_c['volume']

# %%
pricek_inf = np.quantile(diamonds_c['price_k'], 0.01)
pricek_sup = np.quantile(diamonds_c['price_k'], 0.99)
density_inf = np.quantile(diamonds_c['density'], 0.01)
density_sup = np.quantile(diamonds_c['density'], 0.99)

pricek_in = (pricek_inf < diamonds_c['price_k']) &  (diamonds_c['price_k'] < pricek_sup)
density_in = (density_inf < diamonds_c['density']) &  (diamonds_c['density'] < density_sup)
diamonds_c = diamonds_c[pricek_in & density_in].copy()
print('Linhas na etapa atual:', str(len(diamonds_c)))
# Out:
# Linhas na etapa atual: 46973

# %%
diamonds_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46973 entries, 0 to 48939
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   carat        46973 non-null  float64
#  1   cut          46973 non-null  object
#  2   color        46973 non-null  object
#  3   clarity      46973 non-null  object
#  4   depth        46973 non-null  float64
#  5   table        46973 non-null  float64
#  6   price        46973 non-null  int64
#  7   x            46973 non-null  float64
#  8   y            46973 non-null  float64
#  9   z            46973 non-null  float64
#  10  clarity_num  46973 non-null  int64
#  11  color_num    46973 non-null  int64
#  12  volume       46973 non-null  float64
#  13  price_k      46973 non-null  float64
#  14  density      46973 non-null  float64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 5.7+ MB

# %% [markdown]
# # EDA

# %%
sns.pairplot(diamonds_c[['price', 'carat', 'volume', 'x', 'y', 'z']])

# %%
diamonds_c['log_price'] = np.log(diamonds_c['price'])
diamonds_c['log_carat'] = np.log(diamonds_c['carat'])
diamonds_c['std_dim'] = diamonds_c[['x', 'y', 'z']].std(axis = 1, ddof=0)/(diamonds_c[['x', 'y', 'z']].sum(axis = 1))

# %%
sns.pairplot(data = diamonds_c[['log_price', 'log_carat', 'std_dim']])

# %% [markdown]
# Claramente a relação price-carat domina todo o dataset

# %%
X = diamonds_c[['log_carat']]
Y = diamonds_c['log_price']
modelo = LinearRegression()
log_carat_fit = modelo.fit(X, Y)

# %%
diamonds_c['resid_carat_fit'] = diamonds_c['log_price'] - log_carat_fit.predict(X)

# %%
sns.pairplot(data = diamonds_c[['resid_carat_fit', 'depth', 'table', 'color_num', 'clarity_num']])

# %%
sns.pairplot(data = diamonds_c[['resid_carat_fit', 'color_num', 'clarity_num']], kind= 'kde')

# %%
diamonds_c['d_t'] = diamonds_c['depth']/diamonds_c['table']
sns.pairplot(data = diamonds_c[['resid_carat_fit', 'std_dim', 'd_t']])

# %%
sns.pairplot(data = diamonds_c[['resid_carat_fit', 'std_dim', 'd_t']])

# %%
sns.pairplot(diamonds_c[['log_price', 'log_carat', 'volume', 'std_dim', 'clarity']],
            hue = 'clarity')

# %%
sns.pairplot(diamonds_c[['log_price', 'log_carat', 'volume', 'std_dim', 'color']],
            hue = 'color')

# %% [markdown]
# # Modelo I

# %%
string_x = ' ~ log_carat * color_num * clarity_num'
Y, X = patsy.dmatrices('log_price' + string_x, diamonds_c)
modelo = LinearRegression()
lm_fit = modelo.fit(X, Y)
diamonds_c['pred_price'] = np.exp(lm_fit.predict(X))

# %%
sns.scatterplot(data = diamonds_c, x = 'pred_price', y = 'price')
# Out:
# <AxesSubplot:xlabel='pred_price', ylabel='price'>

# %%
tb_rick = pd.read_csv('tb_rick_diamantes.csv')
tb_rick['log_carat'] = np.log(tb_rick['carat'])
tb_rick['std_dim'] = tb_rick[['x', 'y', 'z']].std(axis = 1, ddof=0)/(tb_rick[['x', 'y', 'z']].sum(axis = 1))
tb_rick['clarity_num'] = tb_rick['clarity'].map(dict_clarity)
tb_rick['color_num'] = tb_rick['color'].map(dict_color)
X_rick = patsy.dmatrix(string_x, tb_rick)
tb_rick['price_predicted'] = np.exp(lm_fit.predict(X_rick))
tb_rick.to_csv('price_predicted.csv')

# %% [markdown]
# RMSE = 963.9690720800094

# %% [markdown]
# # Modelo II

# %%
string_x = '~ log_carat * color_num * clarity_num * cut'
Y, X = patsy.dmatrices('log_price' + string_x, diamonds_c)
modelo = LinearRegression()
lm_fit = modelo.fit(X, Y)

# %%
tb_rick = pd.read_csv('tb_rick_diamantes.csv')
tb_rick['log_carat'] = np.log(tb_rick['carat'])
tb_rick['std_dim'] = tb_rick[['x', 'y', 'z']].std(axis = 1, ddof=0)/(tb_rick[['x', 'y', 'z']].sum(axis = 1))
tb_rick['clarity_num'] = tb_rick['clarity'].map(dict_clarity)
tb_rick['color_num'] = tb_rick['color'].map(dict_color)
X_rick = patsy.dmatrix(string_x, tb_rick)
tb_rick['price_predicted'] = np.exp(lm_fit.predict(X_rick))
tb_rick.to_csv('price_predicted.csv')

# %% [markdown]
# RMSE = 835.7330463624712

# %% [markdown]
# # Modelo III

# %%
string_x = '~ log_carat * color_num * clarity_num * cut * depth'
Y, X = patsy.dmatrices('log_price' + string_x, diamonds_c)
modelo = LinearRegression()
lm_fit = modelo.fit(X, Y)

# %%
tb_rick = pd.read_csv('tb_rick_diamantes.csv')
tb_rick['log_carat'] = np.log(tb_rick['carat'])
tb_rick['std_dim'] = tb_rick[['x', 'y', 'z']].std(axis = 1, ddof=0)/(tb_rick[['x', 'y', 'z']].sum(axis = 1))
tb_rick['clarity_num'] = tb_rick['clarity'].map(dict_clarity)
tb_rick['color_num'] = tb_rick['color'].map(dict_color)
X_rick = patsy.dmatrix(string_x, tb_rick)
tb_rick['price_predicted'] = np.exp(lm_fit.predict(X_rick))
tb_rick.to_csv('price_predicted.csv')

# %% [markdown]
# RMSE = 833.3228732846833

# %% [markdown]
# # EDA II

# %%
string_x = '~ log_carat * color_num * clarity_num * cut * depth'
Y, X = patsy.dmatrices('log_price' + string_x, diamonds_c)
log_pred = np.exp(lm_fit.predict(X))
diamonds_c['resid_3'] = diamonds_c['price'] - log_pred[:,0]
diamonds_c['pred_3'] = log_pred[:,0]

# %%
diamonds_c.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z', 'clarity_num', 'color_num', 'volume', 'price_k', 'density',
#        'log_price', 'log_carat', 'std_dim', 'resid_carat_fit', 'd_t',
#        'pred_price', 'resid', 'resid_3', 'max_dim', 'max_dim_classif',
#        'cut_num', 'min_dim', 'prop_dim', 'quality', 'pred_3'],
#       dtype='object')

# %%
sns.pairplot(diamonds_c[['resid_3', 'depth', 'table', 'x', 'y', 'z']])

# %%
diamonds_c['max_dim'] = diamonds_c[['x', 'y', 'z']].max(axis = 1)
diamonds_c['min_dim'] = diamonds_c[['x', 'y', 'z']].min(axis = 1)
diamonds_c['mean_dim'] = diamonds_c[['x', 'y', 'z']].mean(axis = 1)
diamonds_c['prop_dim'] = np.log(diamonds_c['max_dim']/diamonds_c['min_dim'])

# %%
sns.pairplot(data = diamonds_c[['resid_3', 'max_dim', 'min_dim', 'mean_dim']])

# %%
diamonds_c['quality'] = diamonds_c['color_num'] * diamonds_c[
    'clarity_num'] * diamonds_c['cut_num'] * diamonds_c['mean_dim']
diamonds_c['mudim_carat'] = diamonds_c['mean_dim']/diamonds_c['carat']

# %%
sns.pairplot(data = diamonds_c[['resid_3', 'color_num', 'clarity_num', 'cut_num', 'mean_dim']])

# %%
sns.scatterplot(data = diamonds_c, x = 'mudim_carat', y = 'resid_3')
# Out:
# <AxesSubplot:xlabel='mudim_carat', ylabel='resid_3'>

# %%
diamonds_c.loc[:, 'mudim_carat_classif'] = 'PEQUENO'
diamonds_c.loc[diamonds_c['mudim_carat'] > 4, 'mudim_carat_classif'] = '>4'

# %%
diamonds_c.loc[:, 'max_dim_classif'] = 'PEQUENO'
diamonds_c.loc[diamonds_c['max_dim'] > 8, 'max_dim_classif'] = '>8'

# %% [markdown]
# # Modelo IV

# %%
string_x = '~ log_carat * color_num * clarity_num * cut * depth * max_dim_classif + mudim_carat : mudim_carat_classif'
Y, X = patsy.dmatrices('log_price' + string_x, diamonds_c)
modelo = LinearRegression()
lm_fit = modelo.fit(X, Y)

# %%
tb_rick = pd.read_csv('tb_rick_diamantes.csv')
tb_rick['log_carat'] = np.log(tb_rick['carat'])
tb_rick['std_dim'] = tb_rick[['x', 'y', 'z']].std(axis = 1, ddof=0)/(tb_rick[['x', 'y', 'z']].sum(axis = 1))
tb_rick['clarity_num'] = tb_rick['clarity'].map(dict_clarity)
tb_rick['color_num'] = tb_rick['color'].map(dict_color)
tb_rick['max_dim'] = tb_rick[['x', 'y', 'z']].max(axis = 1)
tb_rick['max_dim_classif'] = np.where(tb_rick['max_dim'] > 8, 'GRANDE', 'PEQUENO')
tb_rick['mean_dim'] = tb_rick[['x', 'y', 'z']].mean(axis = 1)
tb_rick['mudim_carat'] = tb_rick['mean_dim']/tb_rick['carat']
tb_rick.loc[:, 'mudim_carat_classif'] = 'PEQUENO'
tb_rick.loc[tb_rick['mudim_carat'] > 4, 'mudim_carat_classif'] = '>4'
X_rick = patsy.dmatrix(string_x, tb_rick)
tb_rick['price_predicted'] = np.exp(lm_fit.predict(X_rick))
tb_rick.to_csv('price_predicted.csv')

# %% [markdown]
# RMSE = 732.6496515918401

# %% [markdown]
# # Modelo V - Partiu ignorância...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
string_x = '~ log_carat + color_num + clarity_num + cut + depth + max_dim_classif'
Y, X = patsy.dmatrices('log_price' + string_x, diamonds_c)
modelo = RandomForestRegressor(n_estimators = 500)
lm_fit = modelo.fit(X, np.array(Y))
# Out:
# <ipython-input-723-7a93e8e0169e>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   lm_fit = modelo.fit(X, Y)

# %%
tb_rick = pd.read_csv('tb_rick_diamantes.csv')
tb_rick['log_carat'] = np.log(tb_rick['carat'])
tb_rick['std_dim'] = tb_rick[['x', 'y', 'z']].std(axis = 1, ddof=0)/(tb_rick[['x', 'y', 'z']].sum(axis = 1))
tb_rick['clarity_num'] = tb_rick['clarity'].map(dict_clarity)
tb_rick['color_num'] = tb_rick['color'].map(dict_color)
tb_rick['max_dim'] = tb_rick[['x', 'y', 'z']].max(axis = 1)
tb_rick.loc[:, 'max_dim_classif'] = 'PEQUENO'
tb_rick.loc[tb_rick['max_dim'] > 8, 'max_dim_classif'] = '>8'
X_rick = patsy.dmatrix(string_x, tb_rick)
tb_rick['price_predicted'] = np.exp(lm_fit.predict(X_rick))
tb_rick.to_csv('price_predicted.csv')

# %% [markdown]
# RMSE = 643.0607725130895
